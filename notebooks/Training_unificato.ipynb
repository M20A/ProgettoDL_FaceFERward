# %% [markdown]
# # Training MobileNetV2 Transfer Learning per FER-2013
#
# Questo notebook addestra un modello MobileNetV2 pre-addestrato su ImageNet per il riconoscimento delle emozioni facciali nel dataset FER-2013.
#
# Usa gli stessi split del progetto:
#
# - `data/processed/train`
# - `data/processed/validation`
# - `data/original/test`
#
# Ogni run viene salvata in `experiments/<timestamp>_mobilenetv2_transfer/`.
# Gli output per documentazione e confronto vengono esportati in `results/`.
#
# Nota: MobileNetV2 usa immagini RGB. Le immagini FER-2013 sono grayscale, quindi vengono caricate come RGB duplicando il canale e ridimensionate a 96x96.

# %% [markdown]
# ## Setup

# %% [markdown]
# Setup iniziale con import delle librerie e definizioni di funzioni di supporto.

# %%
from pathlib import Path
from time import perf_counter
from datetime import datetime
from contextlib import contextmanager
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from keras import Model
from keras.models import load_model
from keras.layers import Input, Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, Callback
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2, ResNet50
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import AUC
from keras.models import Sequential
from keras.layers import Input, Conv2D, MaxPooling2D, Activation, BatchNormalization, Dense, Dropout, GlobalAveragePooling2D, AveragePooling2D, Flatten
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils.class_weight import compute_class_weight
from tf_keras_vis.gradcam import Gradcam

def log_step(message):
    now = datetime.now().strftime("%H:%M:%S")
    print(f"[{now}] {message}", flush=True)


@contextmanager
def timed_step(name):
    start_time = perf_counter()
    log_step(f"INIZIO - {name}")
    try:
        yield
    finally:
        elapsed = perf_counter() - start_time
        log_step(f"FINE - {name} ({elapsed:.1f}s)")


def count_images_by_class(root_dir, extension=".jpg"):
    root_dir = Path(root_dir)
    counts = {}
    if not root_dir.exists():
        return counts

    for class_dir in sorted([p for p in root_dir.iterdir() if p.is_dir()]):
        counts[class_dir.name] = len(list(class_dir.glob(f"*{extension}")))

    return counts


def history_to_frame(history, phase, start_epoch=0):
    frame = pd.DataFrame(history.history)
    frame.insert(0, "phase", phase)
    frame.insert(1, "epoch", np.arange(start_epoch, start_epoch + len(frame)))
    return frame


class EpochTimingLogger(Callback):
    def on_train_begin(self, logs=None):
        self.training_start = perf_counter()
        log_step("Training phase avviata")

    def on_epoch_begin(self, epoch, logs=None):
        self.epoch_start = perf_counter()
        log_step(f"Epoca {epoch + 1} avviata")

    def on_epoch_end(self, epoch, logs=None):
        elapsed = perf_counter() - self.epoch_start
        logs = logs or {}
        metrics = []
        for key in ["loss", "accuracy", "auc", "val_loss", "val_accuracy", "val_auc"]:
            if key in logs:
                metrics.append(f"{key}={logs[key]:.4f}")

        lr = float(tf.keras.backend.get_value(self.model.optimizer.learning_rate))
        metrics.append(f"lr={lr:.2e}")
        log_step(f"Epoca {epoch + 1} completata in {elapsed:.1f}s - " + " | ".join(metrics))

    def on_train_end(self, logs=None):
        elapsed = perf_counter() - self.training_start
        log_step(f"Training phase terminata in {elapsed / 60:.1f} minuti")


SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

log_step(f"TensorFlow: {tf.__version__}")
log_step(f"GPU disponibili: {tf.config.list_physical_devices('GPU')}")
# Out:
# [17:18:29] TensorFlow: 2.20.0
# [17:18:29] GPU disponibili: []

# %% [markdown]
# ### Setup funzione per la stampa del grafico di training (pre-trained)

# %%
def plot_and_save_learning_curves_pretrained(training_history, feature_frame, model_name, output_dir):
    with timed_step(f"Creazione curve {model_name}"):
        fig = plt.figure(figsize=(14, 5))

        split_epoch = len(feature_frame) - 0.5

        # Grafico 1 per l'accuracy
        plt.subplot(1, 2, 1)
        plt.plot(training_history["epoch"], training_history["accuracy"], label="train")
        plt.plot(training_history["epoch"], training_history["val_accuracy"], label="validation")
        plt.axvline(split_epoch, color="gray", linestyle="--", label="inizio fine tuning")
        plt.title(f"{model_name} - Accuracy")
        plt.xlabel("Epoch")
        plt.legend()

        # Grafico 2 per la loss
        plt.subplot(1, 2, 2)
        plt.plot(training_history["epoch"], training_history["loss"], label="train")
        plt.plot(training_history["epoch"], training_history["val_loss"], label="validation")
        plt.axvline(split_epoch, color="gray", linestyle="--", label="inizio fine tuning")
        plt.title(f"{model_name} - Loss")
        plt.xlabel("Epoch")
        plt.legend()

        plt.tight_layout()

        filename = f"{model_name.lower().replace(' ', '_')}_training_curves.png"
        curves_path = Path(output_dir) / filename
        
        fig.savefig(curves_path, dpi=150, bbox_inches="tight")
        log_step(f"Curve di apprendimento salvate in: {curves_path}")

        plt.show()

# %% [markdown]
# ### Setup funzione per la stampa del grafico di training (Custom)

# %%
def plot_training_results_custom(history, model_name, output_dir):

    acc = history.history.get("accuracy")
    val_acc = history.history.get("val_accuracy")
    loss = history.history.get("loss")
    val_loss = history.history.get("val_loss")
    
    epochs_range = range(1, len(loss) + 1)

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

    # Grafico 1 per l'accuracy
    if acc and val_acc:
        ax1.plot(epochs_range, acc, label="Train Accuracy", color="#1f77b4", linewidth=2)
        ax1.plot(epochs_range, val_acc, label="Validation Accuracy", color="#ff7f0e", linewidth=2)
        ax1.set_title(f"{model_name} - Accuracy per Epoca", fontsize=12, fontweight="bold")
        ax1.set_xlabel("Epochs")
        ax1.set_ylabel("Accuracy")
        ax1.legend(loc="lower right")
        ax1.grid(True, linestyle="--", alpha=0.6)

    # Grafico 2 per la Loss
    if loss and val_loss:
        ax2.plot(epochs_range, loss, label="Train Loss", color="#d62728", linewidth=2)
        ax2.plot(epochs_range, val_loss, label="Validation Loss", color="#2ca02c", linewidth=2)
        ax2.set_title(f"{model_name} - Loss per Epoca", fontsize=12, fontweight="bold")
        ax2.set_xlabel("Epochs")
        ax2.set_ylabel("Loss")
        ax2.legend(loc="upper right")
        ax2.grid(True, linestyle="--", alpha=0.6)

    plt.tight_layout()

    filename = f"{model_name.lower()}_curves.png"
    save_path = Path(output_dir) / filename
    
    fig.savefig(save_path, dpi=150, bbox_inches="tight")
    print(f"[INFO] Grafici salvati con successo in: {save_path}")
    plt.show()

# %% [markdown]
# ### Configurazione parametri e iperparametri

# %%
IMG_HEIGHT = 48 #96
IMG_WIDTH = 48 #96
BATCH_SIZE = 32
COLOR = "grayscale" #"rgb"
FEATURE_EPOCHS = 15
FINE_TUNE_EPOCHS = 20
FINE_TUNE_LAST_LAYERS = 30
FEATURE_LEARNING_RATE = 1e-3
FINE_TUNE_LEARNING_RATE = 1e-5

# %% [markdown]
# ### Configurazione percorsi

# %%
with timed_step("Configurazione percorsi MobileNetV2"):
    current_dir = Path.cwd()
    project_root = current_dir if (current_dir / "data").exists() else current_dir.parent

    train_dir = project_root / "data" / "processed" / "train"
    validation_dir = project_root / "data" / "processed" / "validation"
    test_dir = project_root / "data" / "original" / "test"

    experiments_root = project_root / "experiments"
    results_root = project_root / "results"
    results_figures_dir = results_root / "figures"
    results_tables_dir = results_root / "tables"
    results_predictions_dir = results_root / "predictions"

    for output_dir in [experiments_root, results_figures_dir, results_tables_dir, results_predictions_dir]:
        output_dir.mkdir(parents=True, exist_ok=True)


    if not train_dir.exists():
        raise FileNotFoundError(f"Cartella training preprocessata non trovata: {train_dir}. Esegui prima notebooks/Preprocessing.ipynb.")
    if not validation_dir.exists():
        raise FileNotFoundError(f"Cartella validation preprocessata non trovata: {validation_dir}. Esegui prima notebooks/Preprocessing.ipynb.")
    if not test_dir.exists():
        raise FileNotFoundError(f"Cartella test non trovata: {test_dir}")

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    model_name = "mobilenetv2_transfer"
    experiment_dir = experiments_root / f"{timestamp}_{model_name}"
    experiment_dir.mkdir(parents=True, exist_ok=True)

    best_model_path = experiment_dir / "model.keras"
    feature_history_path = experiment_dir / "feature_history.csv"
    fine_tuning_history_path = experiment_dir / "fine_tuning_history.csv"
    training_history_path = experiment_dir / "training_history.csv"
    log_output_path = experiment_dir / "training_log.txt"
    config_path = experiment_dir / "config.json"
    test_results_path = experiment_dir / "test_results.txt"

    log_step(f"Project root: {project_root}")
    log_step(f"Training directory: {train_dir}")
    log_step(f"Validation directory: {validation_dir}")
    log_step(f"Test directory: {test_dir}")
    log_step(f"Experiment directory: {experiment_dir}")
    log_step(f"Input size: {IMG_HEIGHT}x{IMG_WIDTH} RGB")
    log_step(f"Batch size: {BATCH_SIZE}")
# Out:
# [17:19:12] INIZIO - Configurazione percorsi MobileNetV2
# [17:19:12] Project root: c:\Users\Matteo\Documents\GitHub\ProgettoDL_FaceFERward
# [17:19:12] Training directory: c:\Users\Matteo\Documents\GitHub\ProgettoDL_FaceFERward\data\processed\train
# [17:19:12] Validation directory: c:\Users\Matteo\Documents\GitHub\ProgettoDL_FaceFERward\data\processed\validation
# [17:19:12] Test directory: c:\Users\Matteo\Documents\GitHub\ProgettoDL_FaceFERward\data\original\test
# [17:19:12] Experiment directory: c:\Users\Matteo\Documents\GitHub\ProgettoDL_FaceFERward\experiments\20260705_171912_mobilenetv2_transfer
# [17:19:12] Input size: 48x48 RGB
# [17:19:12] Batch size: 32
# [17:19:12] FINE - Configurazione percorsi MobileNetV2 (0.0s)

# %% [markdown]
# ## Generatori e class weights

# %%
# Scegliere in base al modello da utilizzare
#from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
#from tensorflow.keras.applications.resnet50 import preprocess_input


with timed_step("Creazione generatori e class weights"):
    # Per modelli custom
    train_datagen = ImageDataGenerator(rescale=1./255)
    validation_datagen = ImageDataGenerator(rescale=1./255)
    test_datagen = ImageDataGenerator(rescale=1./255)

    # Per modelli pre-trained
    #train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
    #validation_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
    #test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

    log_step("Creo train_generator")
    train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=BATCH_SIZE,
        color_mode=COLOR,
        class_mode="categorical",
        seed=SEED,
    )

    log_step("Creo validation_generator")
    validation_generator = validation_datagen.flow_from_directory(
        validation_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=BATCH_SIZE,
        color_mode=COLOR,
        class_mode="categorical",
        seed=SEED,
        shuffle=False,
    )

    log_step("Creo test_generator RGB")
    test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=BATCH_SIZE,
        color_mode=COLOR,
        class_mode="categorical",
        shuffle=False,
    )

    class_indices = train_generator.class_indices
    emotion_labels = {v: k for k, v in class_indices.items()}
    target_names = [emotion_labels[i] for i in range(len(emotion_labels))]

    class_weights_array = compute_class_weight(
        class_weight="balanced",
        classes=np.unique(train_generator.classes),
        y=train_generator.classes,
    )
    class_weights = dict(enumerate(class_weights_array))

    train_counts = count_images_by_class(train_dir)
    validation_counts = count_images_by_class(validation_dir)
    test_counts = count_images_by_class(test_dir)

    log_step(f"Classi: {class_indices}")
    log_step(f"Training samples: {train_generator.samples} ({len(train_generator)} batch/epoca)")
    log_step(f"Validation samples: {validation_generator.samples} ({len(validation_generator)} batch)")
    log_step(f"Test samples: {test_generator.samples} ({len(test_generator)} batch)")

    for class_name in sorted(set(train_counts) | set(validation_counts) | set(test_counts)):
        log_step(
            f"{class_name}: train={train_counts.get(class_name, 0)}, "
            f"validation={validation_counts.get(class_name, 0)}, "
            f"test={test_counts.get(class_name, 0)}"
        )

    log_step(f"Class weights: {class_weights}")
# Out:
# [17:55:26] INIZIO - Creazione generatori e class weights
# [17:55:26] Creo train_generator
# Found 32155 images belonging to 7 classes.
# [17:55:26] Creo validation_generator
# Found 5741 images belonging to 7 classes.
# [17:55:26] Creo test_generator RGB
# Found 7178 images belonging to 7 classes.
# [17:55:27] Classi: {'angry': 0, 'disgust': 1, 'fear': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}
# [17:55:27] Training samples: 32155 (1005 batch/epoca)
# [17:55:27] Validation samples: 5741 (180 batch)
# [17:55:27] Test samples: 7178 (225 batch)
# [17:55:27] angry: train=4507, validation=799, test=958
# [17:55:27] disgust: train=477, validation=87, test=111
# [17:55:27] fear: train=4588, validation=819, test=1024
# [17:55:27] happy: train=8062, validation=1443, test=1774
# [17:55:27] neutral: train=5560, validation=993, test=1233
# [17:55:27] sad: train=5407, validation=966, test=1247
# [17:55:27] surprise: train=3554, validation=634, test=831
# [17:55:27] Class weights: {0: np.float64(1.0192082157913087), 1: np.float64(9.630128781072177), 2: np.float64(1.0012143479885416), 3: np.float64(0.5697806286990112), 4: np.float64(0.8261819116135662), 5: np.float64(0.8495600940579672), 6: np.float64(1.2925074362890907)}
# [17:55:27] FINE - Creazione generatori e class weights (0.9s)

# %% [markdown]
# ## Modello MobileNetV2

# %% [markdown]
# ### Inizializzazione modello

# %%
with timed_step("Costruzione MobileNetV2 transfer learning"):
    base_model = MobileNetV2(
        weights="imagenet",
        include_top=False,
        input_shape=(96, 96, 3),
    )
    base_model.trainable = False

    inputs = Input(shape=(96, 96, 3))
    x = base_model(inputs, training=False)
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.30)(x)
    outputs = Dense(len(class_indices), activation="softmax")(x)
    model = Model(inputs, outputs, name="mobilenetv2_transfer_fer2013")

    model.compile(
        optimizer=Adam(learning_rate=FEATURE_LEARNING_RATE),
        loss="categorical_crossentropy",
        metrics=["accuracy", AUC(name="auc")],
    )

    total_params = int(model.count_params())
    trainable_params = int(sum(np.prod(v.shape) for v in model.trainable_weights))
    non_trainable_params = total_params - trainable_params

    log_step(f"Parametri totali: {total_params:,}")
    log_step(f"Parametri trainable feature extraction: {trainable_params:,}")
    log_step(f"Parametri non trainable: {non_trainable_params:,}")
    model.summary()
# Out:
# [16:06:40] INIZIO - Costruzione MobileNetV2 transfer learning
# [16:06:41] Parametri totali: 2,266,951
# [16:06:41] Parametri trainable feature extraction: 8,967
# [16:06:41] Parametri non trainable: 2,257,984
# Model: "mobilenetv2_transfer_fer2013"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_96             │ (None, 3, 3, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 7)              │         8,967 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,266,951 (8.65 MB)
#  Trainable params: 8,967 (35.03 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)
# [16:06:41] FINE - Costruzione MobileNetV2 transfer learning (0.6s)

# %% [markdown]
# ### Fase 1 - Feature extraction

# %%
feature_callbacks = [
    EpochTimingLogger(),
    EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2, min_lr=1e-6),
    ModelCheckpoint(str(best_model_path), monitor="val_loss", save_best_only=True),
]

with timed_step("Training MobileNetV2 - feature extraction"):
    feature_start = perf_counter()
    feature_history = model.fit(
        train_generator,
        epochs=FEATURE_EPOCHS,
        validation_data=validation_generator,
        callbacks=feature_callbacks,
        class_weight=class_weights,
        verbose=1,
    )
    feature_train_time_seconds = perf_counter() - feature_start

feature_frame = history_to_frame(feature_history, "feature_extraction", start_epoch=0)
feature_frame.to_csv(feature_history_path, index=False)
log_step(f"Feature extraction history salvata in: {feature_history_path}")
# Out:
# [16:06:45] INIZIO - Training MobileNetV2 - feature extraction
# [16:06:45] Training phase avviata
# [16:06:45] Epoca 1 avviata
# Epoch 1/15
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.2497 - auc: 0.6362 - loss: 2.1427[16:08:35] Epoca 1 completata in 109.9s - loss=1.9631 | accuracy=0.2854 | auc=0.6738 | val_loss=1.7015 | val_accuracy=0.3606 | val_auc=0.7478 | lr=1.00e-03
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 111s 107ms/step - accuracy: 0.2854 - auc: 0.6738 - loss: 1.9631 - val_accuracy: 0.3606 - val_auc: 0.7478 - val_loss: 1.7015 - learning_rate: 0.0010
# [16:08:36] Epoca 2 avviata
# Epoch 2/15
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.3197 - auc: 0.7139 - loss: 1.7973[16:10:13] Epoca 2 completata in 97.3s - loss=1.7737 | accuracy=0.3288 | auc=0.7202 | val_loss=1.5795 | val_accuracy=0.4069 | val_auc=0.7734 | lr=1.00e-03
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 98s 97ms/step - accuracy: 0.3288 - auc: 0.7202 - loss: 1.7737 - val_accuracy: 0.4069 - val_auc: 0.7734 - val_loss: 1.5795 - learning_rate: 0.0010
# [16:10:14] Epoca 3 avviata
# Epoch 3/15
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.3485 - auc: 0.7357 - loss: 1.7135[16:12:10] Epoca 3 completata in 116.8s - loss=1.7393 | accuracy=0.3413 | auc=0.7299 | val_loss=1.6128 | val_accuracy=0.3944 | val_auc=0.7655 | lr=1.00e-03
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 117s 116ms/step - accuracy: 0.3413 - auc: 0.7299 - loss: 1.7393 - val_accuracy: 0.3944 - val_auc: 0.7655 - val_loss: 1.6128 - learning_rate: 0.0010
# [16:12:10] Epoca 4 avviata
# Epoch 4/15
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.3433 - auc: 0.7335 - loss: 1.7150[16:13:46] Epoca 4 completata in 95.1s - loss=1.7284 | accuracy=0.3415 | auc=0.7324 | val_loss=1.6101 | val_accuracy=0.3850 | val_auc=0.7680 | lr=1.00e-03
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 95s 95ms/step - accuracy: 0.3415 - auc: 0.7324 - loss: 1.7284 - val_accuracy: 0.3850 - val_auc: 0.7680 - val_loss: 1.6101 - learning_rate: 0.0010
# [16:13:46] Epoca 5 avviata
# Epoch 5/15
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.3601 - auc: 0.7485 - loss: 1.6477[16:15:34] Epoca 5 completata in 108.7s - loss=1.6558 | accuracy=0.3580 | auc=0.7462 | val_loss=1.5821 | val_accuracy=0.4027 | val_auc=0.7747 | lr=5.00e-04
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 109s 108ms/step - accuracy: 0.3580 - auc: 0.7462 - loss: 1.6558 - val_accuracy: 0.4027 - val_auc: 0.7747 - val_loss: 1.5821 - learning_rate: 5.0000e-04
# [16:15:34] Epoca 6 avviata
# Epoch 6/15
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.3605 - auc: 0.7445 - loss: 1.6789[16:17:58] Epoca 6 completata in 144.0s - loss=1.6561 | accuracy=0.3601 | auc=0.7462 | val_loss=1.5574 | val_accuracy=0.4059 | val_auc=0.7826 | lr=5.00e-04
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 145s 144ms/step - accuracy: 0.3601 - auc: 0.7462 - loss: 1.6561 - val_accuracy: 0.4059 - val_auc: 0.7826 - val_loss: 1.5574 - learning_rate: 5.0000e-04
# [16:17:59] Epoca 7 avviata
# Epoch 7/15
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.3668 - auc: 0.7505 - loss: 1.6259[16:19:50] Epoca 7 completata in 111.4s - loss=1.6428 | accuracy=0.3608 | auc=0.7465 | val_loss=1.6212 | val_accuracy=0.3895 | val_auc=0.7673 | lr=5.00e-04
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 111s 111ms/step - accuracy: 0.3608 - auc: 0.7465 - loss: 1.6428 - val_accuracy: 0.3895 - val_auc: 0.7673 - val_loss: 1.6212 - learning_rate: 5.0000e-04
# [16:19:50] Epoca 8 avviata
# Epoch 8/15
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.3727 - auc: 0.7540 - loss: 1.6282[16:22:35] Epoca 8 completata in 164.7s - loss=1.6415 | accuracy=0.3633 | auc=0.7487 | val_loss=1.6423 | val_accuracy=0.3787 | val_auc=0.7561 | lr=5.00e-04
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 165s 164ms/step - accuracy: 0.3633 - auc: 0.7487 - loss: 1.6415 - val_accuracy: 0.3787 - val_auc: 0.7561 - val_loss: 1.6423 - learning_rate: 5.0000e-04
# [16:22:35] Epoca 9 avviata
# Epoch 9/15
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.3549 - auc: 0.7470 - loss: 1.6521[16:24:16] Epoca 9 completata in 100.7s - loss=1.6291 | accuracy=0.3626 | auc=0.7515 | val_loss=1.6243 | val_accuracy=0.3783 | val_auc=0.7592 | lr=2.50e-04
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 101s 100ms/step - accuracy: 0.3626 - auc: 0.7515 - loss: 1.6291 - val_accuracy: 0.3783 - val_auc: 0.7592 - val_loss: 1.6243 - learning_rate: 2.5000e-04
# [16:24:16] Epoca 10 avviata
# Epoch 10/15
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.3713 - auc: 0.7589 - loss: 1.5976[16:25:59] Epoca 10 completata in 103.0s - loss=1.6089 | accuracy=0.3691 | auc=0.7568 | val_loss=1.5413 | val_accuracy=0.4113 | val_auc=0.7853 | lr=2.50e-04
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 103s 103ms/step - accuracy: 0.3691 - auc: 0.7568 - loss: 1.6089 - val_accuracy: 0.4113 - val_auc: 0.7853 - val_loss: 1.5413 - learning_rate: 2.5000e-04
# [16:25:59] Epoca 11 avviata
# Epoch 11/15
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.3697 - auc: 0.7589 - loss: 1.6095[16:27:44] Epoca 11 completata in 105.1s - loss=1.6059 | accuracy=0.3683 | auc=0.7566 | val_loss=1.5631 | val_accuracy=0.4032 | val_auc=0.7801 | lr=2.50e-04
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 105s 105ms/step - accuracy: 0.3683 - auc: 0.7566 - loss: 1.6059 - val_accuracy: 0.4032 - val_auc: 0.7801 - val_loss: 1.5631 - learning_rate: 2.5000e-04
# [16:27:44] Epoca 12 avviata
# Epoch 12/15
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.3790 - auc: 0.7601 - loss: 1.5946[16:29:47] Epoca 12 completata in 122.9s - loss=1.6001 | accuracy=0.3723 | auc=0.7577 | val_loss=1.5733 | val_accuracy=0.3982 | val_auc=0.7757 | lr=2.50e-04
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 123s 122ms/step - accuracy: 0.3723 - auc: 0.7577 - loss: 1.6001 - val_accuracy: 0.3982 - val_auc: 0.7757 - val_loss: 1.5733 - learning_rate: 2.5000e-04
# [16:29:47] Epoca 13 avviata
# Epoch 13/15
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.3692 - auc: 0.7555 - loss: 1.5977[16:31:38] Epoca 13 completata in 110.6s - loss=1.5930 | accuracy=0.3739 | auc=0.7586 | val_loss=1.5324 | val_accuracy=0.4184 | val_auc=0.7886 | lr=1.25e-04
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 111s 110ms/step - accuracy: 0.3739 - auc: 0.7586 - loss: 1.5930 - val_accuracy: 0.4184 - val_auc: 0.7886 - val_loss: 1.5324 - learning_rate: 1.2500e-04
# [16:31:38] Epoca 14 avviata
# Epoch 14/15
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.3753 - auc: 0.7591 - loss: 1.5899[16:33:26] Epoca 14 completata in 108.0s - loss=1.5862 | accuracy=0.3752 | auc=0.7601 | val_loss=1.5597 | val_accuracy=0.4079 | val_auc=0.7795 | lr=1.25e-04
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 108s 107ms/step - accuracy: 0.3752 - auc: 0.7601 - loss: 1.5862 - val_accuracy: 0.4079 - val_auc: 0.7795 - val_loss: 1.5597 - learning_rate: 1.2500e-04
# [16:33:26] Epoca 15 avviata
# Epoch 15/15
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.3747 - auc: 0.7606 - loss: 1.5721[16:35:09] Epoca 15 completata in 103.3s - loss=1.5864 | accuracy=0.3759 | auc=0.7608 | val_loss=1.5657 | val_accuracy=0.4065 | val_auc=0.7776 | lr=1.25e-04
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 103s 103ms/step - accuracy: 0.3759 - auc: 0.7608 - loss: 1.5864 - val_accuracy: 0.4065 - val_auc: 0.7776 - val_loss: 1.5657 - learning_rate: 1.2500e-04
# [16:35:09] Training phase terminata in 28.4 minuti
# [16:35:09] FINE - Training MobileNetV2 - feature extraction (1704.5s)
# [16:35:10] Feature extraction history salvata in: c:\Users\Matteo\Documents\GitHub\ProgettoDL_FaceFERward\experiments\20260705_160405_mobilenetv2_transfer\feature_history.csv

# %% [markdown]
# ### Fase 2 - Fine tuning

# %%
with timed_step("Configurazione fine tuning MobileNetV2"):
    base_model.trainable = True
    fine_tune_at = max(0, len(base_model.layers) - FINE_TUNE_LAST_LAYERS)

    for layer in base_model.layers[:fine_tune_at]:
        layer.trainable = False

    # Manteniamo BatchNormalization congelata per rendere il fine tuning piu' stabile.
    for layer in base_model.layers:
        if isinstance(layer, BatchNormalization):
            layer.trainable = False

    model.compile(
        optimizer=Adam(learning_rate=FINE_TUNE_LEARNING_RATE),
        loss="categorical_crossentropy",
        metrics=["accuracy", AUC(name="auc")],
    )

    total_params = int(model.count_params())
    fine_tune_trainable_params = int(sum(np.prod(v.shape) for v in model.trainable_weights))
    fine_tune_non_trainable_params = total_params - fine_tune_trainable_params

    log_step(f"Layer totali MobileNetV2: {len(base_model.layers)}")
    log_step(f"Fine tuning dagli ultimi {FINE_TUNE_LAST_LAYERS} layer circa, indice di taglio: {fine_tune_at}")
    log_step(f"Parametri trainable fine tuning: {fine_tune_trainable_params:,}")
    log_step(f"Parametri non trainable fine tuning: {fine_tune_non_trainable_params:,}")


fine_tune_callbacks = [
    EpochTimingLogger(),
    EarlyStopping(monitor="val_loss", patience=6, restore_best_weights=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2, min_lr=1e-7),
    ModelCheckpoint(str(best_model_path), monitor="val_loss", save_best_only=True),
]

with timed_step("Training MobileNetV2 - fine tuning"):
    fine_tune_start = perf_counter()
    fine_tune_history = model.fit(
        train_generator,
        epochs=FINE_TUNE_EPOCHS,
        validation_data=validation_generator,
        callbacks=fine_tune_callbacks,
        class_weight=class_weights,
        verbose=1,
    )
    fine_tune_train_time_seconds = perf_counter() - fine_tune_start

fine_tune_frame = history_to_frame(
    fine_tune_history,
    "fine_tuning",
    start_epoch=len(feature_frame),
)
fine_tune_frame.to_csv(fine_tuning_history_path, index=False)

training_history = pd.concat([feature_frame, fine_tune_frame], ignore_index=True)
training_history.to_csv(training_history_path, index=False)

best_val_loss = float(training_history["val_loss"].min())
best_epoch = int(training_history["val_loss"].idxmin()) + 1
best_val_accuracy = float(training_history["val_accuracy"].max())
best_val_accuracy_epoch = int(training_history["val_accuracy"].idxmax()) + 1
best_val_auc = float(training_history["val_auc"].max())
best_val_auc_epoch = int(training_history["val_auc"].idxmax()) + 1

log_step(f"Training history completa salvata in: {training_history_path}")
log_step(f"Migliore val_loss: {best_val_loss:.4f} all'epoca {best_epoch}")
log_step(f"Migliore val_accuracy: {best_val_accuracy:.4f} all'epoca {best_val_accuracy_epoch}")
log_step(f"Migliore val_auc: {best_val_auc:.4f} all'epoca {best_val_auc_epoch}")
# Out:
# [16:35:22] INIZIO - Configurazione fine tuning MobileNetV2
# [16:35:22] Layer totali MobileNetV2: 154
# [16:35:22] Fine tuning dagli ultimi 30 layer circa, indice di taglio: 124
# [16:35:22] Parametri trainable fine tuning: 1,519,687
# [16:35:22] Parametri non trainable fine tuning: 747,264
# [16:35:22] FINE - Configurazione fine tuning MobileNetV2 (0.1s)
# [16:35:22] INIZIO - Training MobileNetV2 - fine tuning
# [16:35:23] Training phase avviata
# [16:35:23] Epoca 1 avviata
# Epoch 1/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.3801 - auc: 0.7647 - loss: 1.5750[16:37:12] Epoca 1 completata in 109.5s - loss=1.5638 | accuracy=0.3831 | auc=0.7691 | val_loss=1.5310 | val_accuracy=0.4140 | val_auc=0.7872 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 110s 105ms/step - accuracy: 0.3831 - auc: 0.7691 - loss: 1.5638 - val_accuracy: 0.4140 - val_auc: 0.7872 - val_loss: 1.5310 - learning_rate: 1.0000e-05
# [16:37:13] Epoca 2 avviata
# Epoch 2/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.4066 - auc: 0.7823 - loss: 1.5168[16:39:09] Epoca 2 completata in 116.7s - loss=1.5237 | accuracy=0.4030 | auc=0.7814 | val_loss=1.5187 | val_accuracy=0.4229 | val_auc=0.7932 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 117s 116ms/step - accuracy: 0.4030 - auc: 0.7814 - loss: 1.5237 - val_accuracy: 0.4229 - val_auc: 0.7932 - val_loss: 1.5187 - learning_rate: 1.0000e-05
# [16:39:10] Epoca 3 avviata
# Epoch 3/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.4108 - auc: 0.7908 - loss: 1.4844[16:41:02] Epoca 3 completata in 112.3s - loss=1.4683 | accuracy=0.4164 | auc=0.7960 | val_loss=1.5151 | val_accuracy=0.4264 | val_auc=0.7944 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 113s 112ms/step - accuracy: 0.4164 - auc: 0.7960 - loss: 1.4683 - val_accuracy: 0.4264 - val_auc: 0.7944 - val_loss: 1.5151 - learning_rate: 1.0000e-05
# [16:41:02] Epoca 4 avviata
# Epoch 4/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.4243 - auc: 0.7985 - loss: 1.4656[16:42:56] Epoca 4 completata in 113.8s - loss=1.4473 | accuracy=0.4295 | auc=0.8030 | val_loss=1.4203 | val_accuracy=0.4524 | val_auc=0.8219 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 114s 114ms/step - accuracy: 0.4295 - auc: 0.8030 - loss: 1.4473 - val_accuracy: 0.4524 - val_auc: 0.8219 - val_loss: 1.4203 - learning_rate: 1.0000e-05
# [16:42:57] Epoca 5 avviata
# Epoch 5/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.4418 - auc: 0.8111 - loss: 1.4137[16:44:43] Epoca 5 completata in 106.1s - loss=1.4182 | accuracy=0.4413 | auc=0.8103 | val_loss=1.4146 | val_accuracy=0.4625 | val_auc=0.8231 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 106s 106ms/step - accuracy: 0.4413 - auc: 0.8103 - loss: 1.4182 - val_accuracy: 0.4625 - val_auc: 0.8231 - val_loss: 1.4146 - learning_rate: 1.0000e-05
# [16:44:43] Epoca 6 avviata
# Epoch 6/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.4493 - auc: 0.8179 - loss: 1.3829[16:46:37] Epoca 6 completata in 113.9s - loss=1.3829 | accuracy=0.4552 | auc=0.8198 | val_loss=1.4011 | val_accuracy=0.4705 | val_auc=0.8277 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 115s 114ms/step - accuracy: 0.4552 - auc: 0.8198 - loss: 1.3829 - val_accuracy: 0.4705 - val_auc: 0.8277 - val_loss: 1.4011 - learning_rate: 1.0000e-05
# [16:46:38] Epoca 7 avviata
# Epoch 7/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.4544 - auc: 0.8243 - loss: 1.3644[16:48:27] Epoca 7 completata in 109.2s - loss=1.3631 | accuracy=0.4594 | auc=0.8253 | val_loss=1.3872 | val_accuracy=0.4823 | val_auc=0.8317 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 110s 109ms/step - accuracy: 0.4594 - auc: 0.8253 - loss: 1.3631 - val_accuracy: 0.4823 - val_auc: 0.8317 - val_loss: 1.3872 - learning_rate: 1.0000e-05
# [16:48:27] Epoca 8 avviata
# Epoch 8/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.4643 - auc: 0.8275 - loss: 1.3483[16:50:21] Epoca 8 completata in 113.7s - loss=1.3469 | accuracy=0.4668 | auc=0.8297 | val_loss=1.3287 | val_accuracy=0.4978 | val_auc=0.8459 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 114s 114ms/step - accuracy: 0.4668 - auc: 0.8297 - loss: 1.3469 - val_accuracy: 0.4978 - val_auc: 0.8459 - val_loss: 1.3287 - learning_rate: 1.0000e-05
# [16:50:21] Epoca 9 avviata
# Epoch 9/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.4700 - auc: 0.8320 - loss: 1.3263[16:52:33] Epoca 9 completata in 131.9s - loss=1.3215 | accuracy=0.4736 | auc=0.8343 | val_loss=1.3355 | val_accuracy=0.4952 | val_auc=0.8455 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 132s 131ms/step - accuracy: 0.4736 - auc: 0.8343 - loss: 1.3215 - val_accuracy: 0.4952 - val_auc: 0.8455 - val_loss: 1.3355 - learning_rate: 1.0000e-05
# [16:52:33] Epoca 10 avviata
# Epoch 10/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.4837 - auc: 0.8385 - loss: 1.2981[16:54:50] Epoca 10 completata in 136.6s - loss=1.3047 | accuracy=0.4854 | auc=0.8386 | val_loss=1.3238 | val_accuracy=0.5006 | val_auc=0.8478 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 137s 136ms/step - accuracy: 0.4854 - auc: 0.8386 - loss: 1.3047 - val_accuracy: 0.5006 - val_auc: 0.8478 - val_loss: 1.3238 - learning_rate: 1.0000e-05
# [16:54:50] Epoca 11 avviata
# Epoch 11/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.4929 - auc: 0.8440 - loss: 1.2799[16:56:54] Epoca 11 completata in 123.9s - loss=1.2861 | accuracy=0.4898 | auc=0.8428 | val_loss=1.3140 | val_accuracy=0.5055 | val_auc=0.8502 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 124s 124ms/step - accuracy: 0.4898 - auc: 0.8428 - loss: 1.2861 - val_accuracy: 0.5055 - val_auc: 0.8502 - val_loss: 1.3140 - learning_rate: 1.0000e-05
# [16:56:55] Epoca 12 avviata
# Epoch 12/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.4946 - auc: 0.8458 - loss: 1.2724[16:58:47] Epoca 12 completata in 112.0s - loss=1.2663 | accuracy=0.4972 | auc=0.8471 | val_loss=1.3218 | val_accuracy=0.5050 | val_auc=0.8486 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 112s 111ms/step - accuracy: 0.4972 - auc: 0.8471 - loss: 1.2663 - val_accuracy: 0.5050 - val_auc: 0.8486 - val_loss: 1.3218 - learning_rate: 1.0000e-05
# [16:58:47] Epoca 13 avviata
# Epoch 13/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.4997 - auc: 0.8489 - loss: 1.2553[17:00:40] Epoca 13 completata in 113.0s - loss=1.2486 | accuracy=0.5046 | auc=0.8507 | val_loss=1.2890 | val_accuracy=0.5135 | val_auc=0.8572 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 113s 113ms/step - accuracy: 0.5046 - auc: 0.8507 - loss: 1.2486 - val_accuracy: 0.5135 - val_auc: 0.8572 - val_loss: 1.2890 - learning_rate: 1.0000e-05
# [17:00:40] Epoca 14 avviata
# Epoch 14/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.5068 - auc: 0.8533 - loss: 1.2358[17:02:25] Epoca 14 completata in 105.0s - loss=1.2358 | accuracy=0.5070 | auc=0.8537 | val_loss=1.3069 | val_accuracy=0.5013 | val_auc=0.8522 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 105s 104ms/step - accuracy: 0.5070 - auc: 0.8537 - loss: 1.2358 - val_accuracy: 0.5013 - val_auc: 0.8522 - val_loss: 1.3069 - learning_rate: 1.0000e-05
# [17:02:25] Epoca 15 avviata
# Epoch 15/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5102 - auc: 0.8556 - loss: 1.2268[17:04:14] Epoca 15 completata in 108.6s - loss=1.2253 | accuracy=0.5109 | auc=0.8563 | val_loss=1.2804 | val_accuracy=0.5187 | val_auc=0.8595 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 109s 108ms/step - accuracy: 0.5109 - auc: 0.8563 - loss: 1.2253 - val_accuracy: 0.5187 - val_auc: 0.8595 - val_loss: 1.2804 - learning_rate: 1.0000e-05
# [17:04:14] Epoca 16 avviata
# Epoch 16/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.5129 - auc: 0.8595 - loss: 1.2002[17:06:32] Epoca 16 completata in 137.3s - loss=1.2087 | accuracy=0.5121 | auc=0.8595 | val_loss=1.2870 | val_accuracy=0.5179 | val_auc=0.8583 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 137s 137ms/step - accuracy: 0.5121 - auc: 0.8595 - loss: 1.2087 - val_accuracy: 0.5179 - val_auc: 0.8583 - val_loss: 1.2870 - learning_rate: 1.0000e-05
# [17:06:32] Epoca 17 avviata
# Epoch 17/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.5186 - auc: 0.8605 - loss: 1.2011[17:08:34] Epoca 17 completata in 122.2s - loss=1.2019 | accuracy=0.5173 | auc=0.8607 | val_loss=1.2675 | val_accuracy=0.5217 | val_auc=0.8620 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 123s 122ms/step - accuracy: 0.5173 - auc: 0.8607 - loss: 1.2019 - val_accuracy: 0.5217 - val_auc: 0.8620 - val_loss: 1.2675 - learning_rate: 1.0000e-05
# [17:08:34] Epoca 18 avviata
# Epoch 18/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5245 - auc: 0.8636 - loss: 1.1732[17:10:25] Epoca 18 completata in 110.9s - loss=1.1799 | accuracy=0.5267 | auc=0.8648 | val_loss=1.2725 | val_accuracy=0.5189 | val_auc=0.8616 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 111s 110ms/step - accuracy: 0.5267 - auc: 0.8648 - loss: 1.1799 - val_accuracy: 0.5189 - val_auc: 0.8616 - val_loss: 1.2725 - learning_rate: 1.0000e-05
# [17:10:25] Epoca 19 avviata
# Epoch 19/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.5268 - auc: 0.8673 - loss: 1.1731[17:12:41] Epoca 19 completata in 135.7s - loss=1.1787 | accuracy=0.5262 | auc=0.8656 | val_loss=1.2404 | val_accuracy=0.5334 | val_auc=0.8687 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 136s 136ms/step - accuracy: 0.5262 - auc: 0.8656 - loss: 1.1787 - val_accuracy: 0.5334 - val_auc: 0.8687 - val_loss: 1.2404 - learning_rate: 1.0000e-05
# [17:12:42] Epoca 20 avviata
# Epoch 20/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.5380 - auc: 0.8716 - loss: 1.1474[17:15:00] Epoca 20 completata in 138.5s - loss=1.1570 | accuracy=0.5328 | auc=0.8688 | val_loss=1.2598 | val_accuracy=0.5189 | val_auc=0.8637 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 138s 138ms/step - accuracy: 0.5328 - auc: 0.8688 - loss: 1.1570 - val_accuracy: 0.5189 - val_auc: 0.8637 - val_loss: 1.2598 - learning_rate: 1.0000e-05
# [17:15:00] Training phase terminata in 39.6 minuti
# [17:15:00] FINE - Training MobileNetV2 - fine tuning (2377.7s)
# [17:15:00] Training history completa salvata in: c:\Users\Matteo\Documents\GitHub\ProgettoDL_FaceFERward\experiments\20260705_160405_mobilenetv2_transfer\training_history.csv
# [17:15:00] Migliore val_loss: 1.2404 all'epoca 34
# [17:15:00] Migliore val_accuracy: 0.5334 all'epoca 34
# [17:15:00] Migliore val_auc: 0.8687 all'epoca 34

# %% [markdown]
# ### Stampa curve di apprendimento

# %%
plot_and_save_learning_curves_pretrained(training_history, feature_frame, "MobileNetV2", results_figures_dir)
# Out:
# [17:16:35] INIZIO - Creazione curve MobileNetV2
# [17:16:36] Curve di apprendimento salvate in: c:\Users\Matteo\Documents\GitHub\ProgettoDL_FaceFERward\results\figures\mobilenetv2_training_curves.png
# [17:16:36] FINE - Creazione curve MobileNetV2 (0.5s)

# %% [markdown]
# ## Modello ResNet50

# %% [markdown]
# ### Inizializzazione modello

# %%
with timed_step("Costruzione ResNet50 transfer learning"):
    base_model = ResNet50(
        weights="imagenet",
        include_top=False,
        input_shape=(IMG_HEIGHT, IMG_WIDTH, 3),
    )
    base_model.trainable = False

    inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    
    x = base_model(inputs, training=False)
    
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.30)(x)
    
    outputs = Dense(len(class_indices), activation="softmax")(x)
    
    model = Model(inputs, outputs, name="resnet50_transfer_fer2013")

    model.compile(
        optimizer=Adam(learning_rate=FEATURE_LEARNING_RATE),
        loss="categorical_crossentropy",
        metrics=["accuracy", AUC(name="auc")],
    )

    total_params = int(model.count_params())
    trainable_params = int(sum(np.prod(v.shape) for v in model.trainable_weights))
    non_trainable_params = total_params - trainable_params

    log_step(f"Parametri totali: {total_params:,}")
    log_step(f"Parametri trainable feature extraction: {trainable_params:,}")
    log_step(f"Parametri non trainable: {non_trainable_params:,}")
    model.summary()
# Out:
# [13:57:31] INIZIO - Costruzione ResNet50 transfer learning
# [13:57:32] Parametri totali: 23,602,055
# [13:57:32] Parametri trainable feature extraction: 14,343
# [13:57:32] Parametri non trainable: 23,587,712
# Model: "resnet50_transfer_fer2013"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 226, 226, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 8, 8, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │        14,343 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,602,055 (90.03 MB)
#  Trainable params: 14,343 (56.03 KB)
#  Non-trainable params: 23,587,712 (89.98 MB)
# [13:57:32] FINE - Costruzione ResNet50 transfer learning (0.7s)

# %% [markdown]
# ### Fase 1 - Feature extraction

# %%
feature_callbacks = [
    EpochTimingLogger(),
    EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, min_lr=1e-6),
    ModelCheckpoint(str(best_model_path), monitor="val_loss", save_best_only=True),
]

with timed_step("Training ResNet50 - feature extraction"):
    feature_start = perf_counter()
    feature_history = model.fit(
        train_generator,
        epochs=FEATURE_EPOCHS,
        validation_data=validation_generator,
        callbacks=feature_callbacks,
        class_weight=class_weights,
        verbose=1,
    )
    feature_train_time_seconds = perf_counter() - feature_start

feature_frame = history_to_frame(feature_history, "feature_extraction", start_epoch=0)
feature_frame.to_csv(feature_history_path, index=False)
log_step(f"Feature extraction history salvata in: {feature_history_path}")
# Out:
# [13:57:35] INIZIO - Training ResNet50 - feature extraction
# [13:57:35] Training phase avviata
# [13:57:35] Epoca 1 avviata
# Epoch 1/15
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 741ms/step - accuracy: 0.2447 - auc: 0.6323 - loss: 2.0393[14:12:16] Epoca 1 completata in 880.4s - loss=1.9115 | accuracy=0.2836 | auc=0.6732 | val_loss=1.5912 | val_accuracy=0.3952 | val_auc=0.7700 | lr=1.00e-03
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 881s 873ms/step - accuracy: 0.2836 - auc: 0.6732 - loss: 1.9115 - val_accuracy: 0.3952 - val_auc: 0.7700 - val_loss: 1.5912 - learning_rate: 0.0010
# [14:12:16] Epoca 2 avviata
# Epoch 2/15
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 745ms/step - accuracy: 0.3223 - auc: 0.7104 - loss: 1.8109[14:26:55] Epoca 2 completata in 879.0s - loss=1.7692 | accuracy=0.3321 | auc=0.7186 | val_loss=1.4433 | val_accuracy=0.4574 | val_auc=0.8162 | lr=1.00e-03
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 880s 875ms/step - accuracy: 0.3321 - auc: 0.7186 - loss: 1.7692 - val_accuracy: 0.4574 - val_auc: 0.8162 - val_loss: 1.4433 - learning_rate: 0.0010
# [14:26:56] Epoca 3 avviata
# Epoch 3/15
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 748ms/step - accuracy: 0.3392 - auc: 0.7292 - loss: 1.7470[14:41:39] Epoca 3 completata in 883.2s - loss=1.7379 | accuracy=0.3425 | auc=0.7309 | val_loss=1.4417 | val_accuracy=0.4525 | val_auc=0.8153 | lr=1.00e-03
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 884s 879ms/step - accuracy: 0.3425 - auc: 0.7309 - loss: 1.7379 - val_accuracy: 0.4525 - val_auc: 0.8153 - val_loss: 1.4417 - learning_rate: 0.0010
# [14:41:40] Epoca 4 avviata
# Epoch 4/15
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 748ms/step - accuracy: 0.3427 - auc: 0.7351 - loss: 1.7112[14:56:21] Epoca 4 completata in 881.5s - loss=1.7246 | accuracy=0.3426 | auc=0.7344 | val_loss=1.4831 | val_accuracy=0.4438 | val_auc=0.8034 | lr=1.00e-03
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 881s 877ms/step - accuracy: 0.3426 - auc: 0.7344 - loss: 1.7246 - val_accuracy: 0.4438 - val_auc: 0.8034 - val_loss: 1.4831 - learning_rate: 0.0010
# [14:56:21] Epoca 5 avviata
# Epoch 5/15
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 742ms/step - accuracy: 0.3411 - auc: 0.7330 - loss: 1.7330[15:10:56] Epoca 5 completata in 874.6s - loss=1.7286 | accuracy=0.3469 | auc=0.7351 | val_loss=1.4810 | val_accuracy=0.4398 | val_auc=0.8051 | lr=1.00e-03
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 875s 870ms/step - accuracy: 0.3469 - auc: 0.7351 - loss: 1.7286 - val_accuracy: 0.4398 - val_auc: 0.8051 - val_loss: 1.4810 - learning_rate: 0.0010
# [15:10:56] Epoca 6 avviata
# Epoch 6/15
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 743ms/step - accuracy: 0.3565 - auc: 0.7430 - loss: 1.6941[15:25:32] Epoca 6 completata in 875.4s - loss=1.7176 | accuracy=0.3511 | auc=0.7390 | val_loss=1.4524 | val_accuracy=0.4585 | val_auc=0.8156 | lr=1.00e-03
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 875s 871ms/step - accuracy: 0.3511 - auc: 0.7390 - loss: 1.7176 - val_accuracy: 0.4585 - val_auc: 0.8156 - val_loss: 1.4524 - learning_rate: 0.0010
# [15:25:32] Epoca 7 avviata
# Epoch 7/15
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 745ms/step - accuracy: 0.3654 - auc: 0.7487 - loss: 1.6677[15:40:11] Epoca 7 completata in 879.0s - loss=1.6597 | accuracy=0.3660 | auc=0.7501 | val_loss=1.4515 | val_accuracy=0.4632 | val_auc=0.8133 | lr=5.00e-04
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 879s 875ms/step - accuracy: 0.3660 - auc: 0.7501 - loss: 1.6597 - val_accuracy: 0.4632 - val_auc: 0.8133 - val_loss: 1.4515 - learning_rate: 5.0000e-04
# [15:40:11] Epoca 8 avviata
# Epoch 8/15
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 745ms/step - accuracy: 0.3660 - auc: 0.7498 - loss: 1.6493[15:54:48] Epoca 8 completata in 877.4s - loss=1.6553 | accuracy=0.3626 | auc=0.7497 | val_loss=1.4797 | val_accuracy=0.4485 | val_auc=0.8055 | lr=5.00e-04
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 877s 873ms/step - accuracy: 0.3626 - auc: 0.7497 - loss: 1.6553 - val_accuracy: 0.4485 - val_auc: 0.8055 - val_loss: 1.4797 - learning_rate: 5.0000e-04
# [15:54:48] Training phase terminata in 117.2 minuti
# [15:54:48] FINE - Training ResNet50 - feature extraction (7033.2s)
# [15:54:48] Feature extraction history salvata in: c:\Users\Matteo\Documents\GitHub\ProgettoDL_FaceFERward\experiments\20260630_135725_ResNet50_transfer\feature_history.csv

# %% [markdown]
# ### Fase 2 - Fine tuning

# %%
with timed_step("Configurazione fine tuning ResNet50"):
    base_model.trainable = True
    fine_tune_at = max(0, len(base_model.layers) - FINE_TUNE_LAST_LAYERS)

    for layer in base_model.layers[:fine_tune_at]:
        layer.trainable = False

    for layer in base_model.layers:
        if isinstance(layer, BatchNormalization):
            layer.trainable = False

    model.compile(
        optimizer=Adam(learning_rate=FINE_TUNE_LEARNING_RATE),
        loss="categorical_crossentropy",
        metrics=["accuracy", AUC(name="auc")],
    )

    total_params = int(model.count_params())
    fine_tune_trainable_params = int(sum(np.prod(v.shape) for v in model.trainable_weights))
    fine_tune_non_trainable_params = total_params - fine_tune_trainable_params

    log_step(f"Layer totali ResNet50: {len(base_model.layers)}")
    log_step(f"Fine tuning dagli ultimi {FINE_TUNE_LAST_LAYERS} layer circa, indice di taglio: {fine_tune_at}")
    log_step(f"Parametri trainable fine tuning: {fine_tune_trainable_params:,}")
    log_step(f"Parametri non trainable fine tuning: {fine_tune_non_trainable_params:,}")


fine_tune_callbacks = [
    EpochTimingLogger(),
    EarlyStopping(monitor="val_loss", patience=6, restore_best_weights=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2, min_lr=1e-7),
    ModelCheckpoint(str(best_model_path), monitor="val_loss", save_best_only=True),
]

with timed_step("Training ResNet50 - fine tuning"):
    fine_tune_start = perf_counter()
    fine_tune_history = model.fit(
        train_generator,
        epochs=FINE_TUNE_EPOCHS,
        validation_data=validation_generator,
        callbacks=fine_tune_callbacks,
        class_weight=class_weights,
        verbose=1,
    )
    fine_tune_train_time_seconds = perf_counter() - fine_tune_start

fine_tune_frame = history_to_frame(
    fine_tune_history,
    "fine_tuning",
    start_epoch=len(feature_frame),
)
fine_tune_frame.to_csv(fine_tuning_history_path, index=False)

training_history = pd.concat([feature_frame, fine_tune_frame], ignore_index=True)
training_history.to_csv(training_history_path, index=False)

best_val_loss = float(training_history["val_loss"].min())
best_epoch = int(training_history["val_loss"].idxmin()) + 1
best_val_accuracy = float(training_history["val_accuracy"].max())
best_val_accuracy_epoch = int(training_history["val_accuracy"].idxmax()) + 1
best_val_auc = float(training_history["val_auc"].max())
best_val_auc_epoch = int(training_history["val_auc"].idxmax()) + 1

log_step(f"Training history completa salvata in: {training_history_path}")
log_step(f"Migliore val_loss: {best_val_loss:.4f} all'epoca {best_epoch}")
log_step(f"Migliore val_accuracy: {best_val_accuracy:.4f} all'epoca {best_val_accuracy_epoch}")
log_step(f"Migliore val_auc: {best_val_auc:.4f} all'epoca {best_val_auc_epoch}")
# Out:
# [15:54:48] INIZIO - Configurazione fine tuning ResNet50
# [15:54:48] Layer totali ResNet50: 175
# [15:54:48] Fine tuning dagli ultimi 30 layer circa, indice di taglio: 145
# [15:54:48] Parametri trainable fine tuning: 14,443,015
# [15:54:48] Parametri non trainable fine tuning: 9,159,040
# [15:54:48] FINE - Configurazione fine tuning ResNet50 (0.0s)
# [15:54:48] INIZIO - Training ResNet50 - fine tuning
# [15:54:49] Training phase avviata
# [15:54:49] Epoca 1 avviata
# Epoch 1/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3756 - auc: 0.7566 - loss: 1.6293[16:14:04] Epoca 1 completata in 1161.8s - loss=1.5654 | accuracy=0.3950 | auc=0.7735 | val_loss=1.3810 | val_accuracy=0.4868 | val_auc=0.8354 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 1157s 1s/step - accuracy: 0.3950 - auc: 0.7735 - loss: 1.5654 - val_accuracy: 0.4868 - val_auc: 0.8354 - val_loss: 1.3810 - learning_rate: 1.0000e-05
# [16:14:05] Epoca 2 avviata
# Epoch 2/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4319 - auc: 0.8037 - loss: 1.4748[16:34:38] Epoca 2 completata in 1232.9s - loss=1.4446 | accuracy=0.4425 | auc=0.8108 | val_loss=1.2620 | val_accuracy=0.5274 | val_auc=0.8633 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 1234s 1s/step - accuracy: 0.4425 - auc: 0.8108 - loss: 1.4446 - val_accuracy: 0.5274 - val_auc: 0.8633 - val_loss: 1.2620 - learning_rate: 1.0000e-05
# [16:34:39] Epoca 3 avviata
# Epoch 3/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4682 - auc: 0.8273 - loss: 1.3837[16:55:02] Epoca 3 completata in 1222.6s - loss=1.3627 | accuracy=0.4740 | auc=0.8322 | val_loss=1.2270 | val_accuracy=0.5339 | val_auc=0.8714 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 1224s 1s/step - accuracy: 0.4740 - auc: 0.8322 - loss: 1.3627 - val_accuracy: 0.5339 - val_auc: 0.8714 - val_loss: 1.2270 - learning_rate: 1.0000e-05
# [16:55:03] Epoca 4 avviata
# Epoch 4/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4944 - auc: 0.8497 - loss: 1.2983[17:14:18] Epoca 4 completata in 1155.3s - loss=1.2992 | accuracy=0.4949 | auc=0.8486 | val_loss=1.1894 | val_accuracy=0.5515 | val_auc=0.8794 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 1156s 1s/step - accuracy: 0.4949 - auc: 0.8486 - loss: 1.2992 - val_accuracy: 0.5515 - val_auc: 0.8794 - val_loss: 1.1894 - learning_rate: 1.0000e-05
# [17:14:20] Epoca 5 avviata
# Epoch 5/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5121 - auc: 0.8562 - loss: 1.2607[17:33:27] Epoca 5 completata in 1147.7s - loss=1.2497 | accuracy=0.5151 | auc=0.8579 | val_loss=1.1310 | val_accuracy=0.5663 | val_auc=0.8913 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 1149s 1s/step - accuracy: 0.5151 - auc: 0.8579 - loss: 1.2497 - val_accuracy: 0.5663 - val_auc: 0.8913 - val_loss: 1.1310 - learning_rate: 1.0000e-05
# [17:33:28] Epoca 6 avviata
# Epoch 6/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5312 - auc: 0.8665 - loss: 1.2016[17:52:31] Epoca 6 completata in 1142.2s - loss=1.1928 | accuracy=0.5325 | auc=0.8681 | val_loss=1.1443 | val_accuracy=0.5666 | val_auc=0.8899 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 1142s 1s/step - accuracy: 0.5325 - auc: 0.8681 - loss: 1.1928 - val_accuracy: 0.5666 - val_auc: 0.8899 - val_loss: 1.1443 - learning_rate: 1.0000e-05
# [17:52:31] Epoca 7 avviata
# Epoch 7/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 966ms/step - accuracy: 0.5465 - auc: 0.8755 - loss: 1.1582[18:10:48] Epoca 7 completata in 1097.7s - loss=1.1668 | accuracy=0.5458 | auc=0.8748 | val_loss=1.1040 | val_accuracy=0.5820 | val_auc=0.8971 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 1099s 1s/step - accuracy: 0.5458 - auc: 0.8748 - loss: 1.1668 - val_accuracy: 0.5820 - val_auc: 0.8971 - val_loss: 1.1040 - learning_rate: 1.0000e-05
# [18:10:49] Epoca 8 avviata
# Epoch 8/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 980ms/step - accuracy: 0.5542 - auc: 0.8805 - loss: 1.1333[18:29:22] Epoca 8 completata in 1112.6s - loss=1.1229 | accuracy=0.5570 | auc=0.8820 | val_loss=1.0872 | val_accuracy=0.5813 | val_auc=0.8997 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 1114s 1s/step - accuracy: 0.5570 - auc: 0.8820 - loss: 1.1229 - val_accuracy: 0.5813 - val_auc: 0.8997 - val_loss: 1.0872 - learning_rate: 1.0000e-05
# [18:29:23] Epoca 9 avviata
# Epoch 9/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5629 - auc: 0.8851 - loss: 1.1056[18:52:09] Epoca 9 completata in 1366.1s - loss=1.0951 | accuracy=0.5655 | auc=0.8871 | val_loss=1.1252 | val_accuracy=0.5708 | val_auc=0.8926 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 1366s 1s/step - accuracy: 0.5655 - auc: 0.8871 - loss: 1.0951 - val_accuracy: 0.5708 - val_auc: 0.8926 - val_loss: 1.1252 - learning_rate: 1.0000e-05
# [18:52:09] Epoca 10 avviata
# Epoch 10/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5757 - auc: 0.8928 - loss: 1.0605[19:12:45] Epoca 10 completata in 1235.5s - loss=1.0608 | accuracy=0.5761 | auc=0.8927 | val_loss=1.0706 | val_accuracy=0.5973 | val_auc=0.9046 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 1237s 1s/step - accuracy: 0.5761 - auc: 0.8927 - loss: 1.0608 - val_accuracy: 0.5973 - val_auc: 0.9046 - val_loss: 1.0706 - learning_rate: 1.0000e-05
# [19:12:46] Epoca 11 avviata
# Epoch 11/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5900 - auc: 0.8983 - loss: 1.0335[19:32:01] Epoca 11 completata in 1155.0s - loss=1.0391 | accuracy=0.5855 | auc=0.8971 | val_loss=1.0607 | val_accuracy=0.5969 | val_auc=0.9049 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 1156s 1s/step - accuracy: 0.5855 - auc: 0.8971 - loss: 1.0391 - val_accuracy: 0.5969 - val_auc: 0.9049 - val_loss: 1.0607 - learning_rate: 1.0000e-05
# [19:32:02] Epoca 12 avviata
# Epoch 12/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5910 - auc: 0.9026 - loss: 1.0107[19:51:08] Epoca 12 completata in 1146.0s - loss=1.0153 | accuracy=0.5899 | auc=0.9017 | val_loss=1.0635 | val_accuracy=0.5985 | val_auc=0.9048 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 1146s 1s/step - accuracy: 0.5899 - auc: 0.9017 - loss: 1.0153 - val_accuracy: 0.5985 - val_auc: 0.9048 - val_loss: 1.0635 - learning_rate: 1.0000e-05
# [19:51:08] Epoca 13 avviata
# Epoch 13/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6014 - auc: 0.9067 - loss: 0.9722[20:10:08] Epoca 13 completata in 1140.0s - loss=0.9883 | accuracy=0.5993 | auc=0.9050 | val_loss=1.0637 | val_accuracy=0.6020 | val_auc=0.9048 | lr=1.00e-05
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 1140s 1s/step - accuracy: 0.5993 - auc: 0.9050 - loss: 0.9883 - val_accuracy: 0.6020 - val_auc: 0.9048 - val_loss: 1.0637 - learning_rate: 1.0000e-05
# [20:10:08] Epoca 14 avviata
# Epoch 14/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6144 - auc: 0.9124 - loss: 0.9422[20:29:08] Epoca 14 completata in 1140.0s - loss=0.9282 | accuracy=0.6179 | auc=0.9142 | val_loss=1.0438 | val_accuracy=0.6098 | val_auc=0.9098 | lr=5.00e-06
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 1141s 1s/step - accuracy: 0.6179 - auc: 0.9142 - loss: 0.9282 - val_accuracy: 0.6098 - val_auc: 0.9098 - val_loss: 1.0438 - learning_rate: 5.0000e-06
# [20:29:09] Epoca 15 avviata
# Epoch 15/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6230 - auc: 0.9163 - loss: 0.9205[20:48:13] Epoca 15 completata in 1144.2s - loss=0.9200 | accuracy=0.6234 | auc=0.9163 | val_loss=1.0310 | val_accuracy=0.6147 | val_auc=0.9118 | lr=5.00e-06
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 1145s 1s/step - accuracy: 0.6234 - auc: 0.9163 - loss: 0.9200 - val_accuracy: 0.6147 - val_auc: 0.9118 - val_loss: 1.0310 - learning_rate: 5.0000e-06
# [20:48:15] Epoca 16 avviata
# Epoch 16/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6340 - auc: 0.9195 - loss: 0.8977[21:07:18] Epoca 16 completata in 1142.9s - loss=0.9051 | accuracy=0.6287 | auc=0.9183 | val_loss=1.0389 | val_accuracy=0.6147 | val_auc=0.9102 | lr=5.00e-06
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 1143s 1s/step - accuracy: 0.6287 - auc: 0.9183 - loss: 0.9051 - val_accuracy: 0.6147 - val_auc: 0.9102 - val_loss: 1.0389 - learning_rate: 5.0000e-06
# [21:07:18] Epoca 17 avviata
# Epoch 17/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6383 - auc: 0.9217 - loss: 0.8798[21:26:22] Epoca 17 completata in 1144.2s - loss=0.8870 | accuracy=0.6373 | auc=0.9207 | val_loss=1.0703 | val_accuracy=0.6090 | val_auc=0.9061 | lr=5.00e-06
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 1144s 1s/step - accuracy: 0.6373 - auc: 0.9207 - loss: 0.8870 - val_accuracy: 0.6090 - val_auc: 0.9061 - val_loss: 1.0703 - learning_rate: 5.0000e-06
# [21:26:22] Epoca 18 avviata
# Epoch 18/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6373 - auc: 0.9244 - loss: 0.8618[21:45:21] Epoca 18 completata in 1138.9s - loss=0.8567 | accuracy=0.6418 | auc=0.9253 | val_loss=1.0456 | val_accuracy=0.6215 | val_auc=0.9114 | lr=2.50e-06
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 1139s 1s/step - accuracy: 0.6418 - auc: 0.9253 - loss: 0.8567 - val_accuracy: 0.6215 - val_auc: 0.9114 - val_loss: 1.0456 - learning_rate: 2.5000e-06
# [21:45:21] Epoca 19 avviata
# Epoch 19/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6479 - auc: 0.9269 - loss: 0.8424[22:06:04] Epoca 19 completata in 1243.4s - loss=0.8490 | accuracy=0.6483 | auc=0.9263 | val_loss=1.0408 | val_accuracy=0.6171 | val_auc=0.9114 | lr=2.50e-06
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 1243s 1s/step - accuracy: 0.6483 - auc: 0.9263 - loss: 0.8490 - val_accuracy: 0.6171 - val_auc: 0.9114 - val_loss: 1.0408 - learning_rate: 2.5000e-06
# [22:06:04] Epoca 20 avviata
# Epoch 20/20
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6524 - auc: 0.9289 - loss: 0.8321[22:26:15] Epoca 20 completata in 1210.6s - loss=0.8373 | accuracy=0.6525 | auc=0.9286 | val_loss=1.0375 | val_accuracy=0.6229 | val_auc=0.9126 | lr=1.25e-06
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 1211s 1s/step - accuracy: 0.6525 - auc: 0.9286 - loss: 0.8373 - val_accuracy: 0.6229 - val_auc: 0.9126 - val_loss: 1.0375 - learning_rate: 1.2500e-06
# [22:26:15] Training phase terminata in 391.5 minuti
# [22:26:15] FINE - Training ResNet50 - fine tuning (23493.3s)
# [22:26:15] Training history completa salvata in: c:\Users\Matteo\Documents\GitHub\ProgettoDL_FaceFERward\experiments\20260630_135725_ResNet50_transfer\training_history.csv
# [22:26:15] Migliore val_loss: 1.0310 all'epoca 23
# [22:26:15] Migliore val_accuracy: 0.6229 all'epoca 28
# [22:26:15] Migliore val_auc: 0.9126 all'epoca 28

# %% [markdown]
# ### Stampa curve di apprendimento

# %%
plot_and_save_learning_curves(training_history, feature_frame, "MobileNetV2", results_figures_dir)
# Out:
# [22:26:15] INIZIO - Creazione curve ResNet50
# [22:26:16] Curve di apprendimento salvate in: c:\Users\Matteo\Documents\GitHub\ProgettoDL_FaceFERward\results\figures\20260630_135725_ResNet50_transfer_training_curves.png
# [22:26:16] FINE - Creazione curve ResNet50 (0.5s)

# %% [markdown]
# ## Modello CNN custom v1

# %% [markdown]
# ### Inizializzazione modello

# %%
with timed_step("Costruzione e compilazione modello CNN"):
    input_shape = (IMG_HEIGHT, IMG_WIDTH, 1)

    modelCNN = Sequential([
        Input(shape=input_shape),

        Conv2D(16, (3, 3), padding="same"),
        Activation("relu"),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),

        Conv2D(32, (3, 3), padding="same"),
        Activation("relu"),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),

        Conv2D(64, (3, 3), padding="same"),
        Activation("relu"),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),

        Conv2D(128, (3, 3), padding="same"),
        Activation("relu"),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),

        GlobalAveragePooling2D(),

        Dense(128, activation="relu"),
        Dropout(0.4),

        Dense(train_generator.num_classes, activation="softmax")
    ])

    optimizer = tf.keras.optimizers.Adam(learning_rate=3e-4)

    modelCNN.compile(
        optimizer=optimizer,
        loss="categorical_crossentropy",
        metrics=["accuracy", tf.keras.metrics.AUC(name="auc")]
    )

    modelCNN.summary()
# Out:
# [17:55:32] INIZIO - Costruzione e compilazione modello CNN
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_16 (Conv2D)              │ (None, 48, 48, 16)     │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_16 (Activation)      │ (None, 48, 48, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 48, 48, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ (None, 24, 24, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 24, 24, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_17 (Activation)      │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 24, 24, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (None, 12, 12, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (None, 12, 12, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_18 (Activation)      │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 12, 12, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_18 (MaxPooling2D) │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 6, 6, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_19 (Activation)      │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 6, 6, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_19 (MaxPooling2D) │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_5      │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 115,527 (451.28 KB)
#  Trainable params: 115,047 (449.40 KB)
#  Non-trainable params: 480 (1.88 KB)
# [17:55:32] FINE - Costruzione e compilazione modello CNN (0.1s)

# %% [markdown]
# ### Training CNN custom

# %%
import json
import sys
from tensorflow.keras.callbacks import CSVLogger

# Forza il ripristino del modulo originale pulito direttamente dal sistema.
datetime_module = sys.modules["datetime"]
log_step.__globals__["datetime"] = datetime_module.datetime

with timed_step("Training modello"):
    timestamp = datetime_module.datetime.now().strftime("%Y%m%d_%H%M%S")
    model_name = "cnn_v1"

    experiments_root = project_root / "experiments"
    specific_model_dir = experiments_root / f"{timestamp}_{model_name}"
    specific_model_dir.mkdir(parents=True, exist_ok=True)

    results_root = project_root / "results"
    results_figures_dir = results_root / "figures"
    results_tables_dir = results_root / "tables"
    results_predictions_dir = results_root / "predictions"
    for output_dir in [results_figures_dir, results_tables_dir, results_predictions_dir]:
        output_dir.mkdir(parents=True, exist_ok=True)

    best_model_path = specific_model_dir / "model.keras"
    history_csv_path = specific_model_dir / "training_history.csv"
    log_output_path = specific_model_dir / "training_log.txt"
    config_path = specific_model_dir / "config.json"

    config = {
        "model_name": model_name,
        "timestamp": timestamp,
        "input_shape": [IMG_HEIGHT, IMG_WIDTH, 1],
        "batch_size": BATCH_SIZE,
        "epochs": 50,
        "optimizer": "Adam",
        "learning_rate": 3e-4,
        "loss": "categorical_crossentropy",
        "metrics": ["accuracy", "auc"],
        "class_weight": {str(k): float(v) for k, v in class_weights.items()},
        "train_dir": str(train_dir.relative_to(project_root)),
        "validation_dir": str(validation_dir.relative_to(project_root)),
        "test_dir": str(test_dir.relative_to(project_root)),
        "output_dir": str(specific_model_dir.relative_to(project_root)),
    }

    with open(config_path, "w", encoding="utf-8") as f:
        json.dump(config, f, indent=2)

    log_step(f"I risultati del modello verranno salvati in: {specific_model_dir}")
    log_step("Callback attivi: EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, EpochTimingLogger, CSVLogger")

    callbacks = [
        EpochTimingLogger(),
        EarlyStopping(monitor="val_loss", patience=8, restore_best_weights=True),
        ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, min_lr=1e-6),
        ModelCheckpoint(str(best_model_path), monitor="val_loss", save_best_only=True),
        CSVLogger(str(history_csv_path), separator=",", append=False),
    ]

    history = modelCNN.fit(
        train_generator,
        epochs=config["epochs"],
        validation_data=validation_generator,
        callbacks=callbacks,
        class_weight=class_weights,
        verbose=1,
    )

    best_val_loss = min(history.history["val_loss"])
    best_epoch = history.history["val_loss"].index(best_val_loss) + 1

    summary_message = f"Migliore val_loss: {best_val_loss:.4f} all'epoca {best_epoch}"
    log_step(summary_message)

    with open(log_output_path, "w", encoding="utf-8") as f:
        f.write(f"Modello: {model_name}\n")
        f.write(f"Data: {timestamp}\n")
        f.write(f"{summary_message}\n")
        summary_message = f"Migliore val_loss: {best_val_loss:.4f} all'epoca {best_epoch}"
    log_step(summary_message)

    with open(log_output_path, "w", encoding="utf-8") as f:
        f.write(f"Modello: {model_name}\n")
        f.write(f"Data: {timestamp}\n")
        f.write(f"{summary_message}\n")
# Out:
# [18:22:44] INIZIO - Training modello
# [18:22:44] I risultati del modello verranno salvati in: c:\Users\Matteo\Documents\GitHub\ProgettoDL_FaceFERward\experiments\20260705_182244_cnn_v1
# [18:22:44] Callback attivi: EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, EpochTimingLogger, CSVLogger
# [18:22:44] Training phase avviata
# [18:22:44] Epoca 1 avviata
# Epoch 1/50
# 1002/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6808 - auc: 0.9390 - loss: 0.7543[18:23:05] Epoca 1 completata in 21.5s - loss=0.7552 | accuracy=0.6783 | auc=0.9385 | val_loss=1.2747 | val_accuracy=0.5442 | val_auc=0.8731 | lr=9.38e-06
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 22s 21ms/step - accuracy: 0.6783 - auc: 0.9385 - loss: 0.7552 - val_accuracy: 0.5442 - val_auc: 0.8731 - val_loss: 1.2747 - learning_rate: 9.3750e-06
# [18:23:06] Epoca 2 avviata
# Epoch 2/50
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6802 - auc: 0.9389 - loss: 0.7520[18:23:32] Epoca 2 completata in 26.2s - loss=0.7476 | accuracy=0.6814 | auc=0.9397 | val_loss=1.2765 | val_accuracy=0.5424 | val_auc=0.8730 | lr=9.38e-06
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 26s 26ms/step - accuracy: 0.6814 - auc: 0.9397 - loss: 0.7476 - val_accuracy: 0.5424 - val_auc: 0.8730 - val_loss: 1.2765 - learning_rate: 9.3750e-06
# [18:23:32] Epoca 3 avviata
# Epoch 3/50
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6786 - auc: 0.9399 - loss: 0.7475[18:23:59] Epoca 3 completata in 27.3s - loss=0.7423 | accuracy=0.6828 | auc=0.9405 | val_loss=1.2806 | val_accuracy=0.5442 | val_auc=0.8727 | lr=9.38e-06
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 27s 27ms/step - accuracy: 0.6828 - auc: 0.9405 - loss: 0.7423 - val_accuracy: 0.5442 - val_auc: 0.8727 - val_loss: 1.2806 - learning_rate: 9.3750e-06
# [18:23:59] Epoca 4 avviata
# Epoch 4/50
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6915 - auc: 0.9424 - loss: 0.7301[18:24:32] Epoca 4 completata in 33.4s - loss=0.7369 | accuracy=0.6864 | auc=0.9413 | val_loss=1.2844 | val_accuracy=0.5447 | val_auc=0.8724 | lr=9.38e-06
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 33s 33ms/step - accuracy: 0.6864 - auc: 0.9413 - loss: 0.7369 - val_accuracy: 0.5447 - val_auc: 0.8724 - val_loss: 1.2844 - learning_rate: 9.3750e-06
# [18:24:32] Epoca 5 avviata
# Epoch 5/50
# 1004/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6901 - auc: 0.9432 - loss: 0.7236[18:25:07] Epoca 5 completata in 34.6s - loss=0.7312 | accuracy=0.6881 | auc=0.9423 | val_loss=1.2860 | val_accuracy=0.5419 | val_auc=0.8721 | lr=4.69e-06
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 35s 34ms/step - accuracy: 0.6881 - auc: 0.9423 - loss: 0.7312 - val_accuracy: 0.5419 - val_auc: 0.8721 - val_loss: 1.2860 - learning_rate: 4.6875e-06
# [18:25:07] Epoca 6 avviata
# Epoch 6/50
# 1003/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6871 - auc: 0.9419 - loss: 0.7311[18:25:37] Epoca 6 completata in 29.9s - loss=0.7318 | accuracy=0.6889 | auc=0.9421 | val_loss=1.2891 | val_accuracy=0.5422 | val_auc=0.8722 | lr=4.69e-06
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 30s 30ms/step - accuracy: 0.6889 - auc: 0.9421 - loss: 0.7318 - val_accuracy: 0.5422 - val_auc: 0.8722 - val_loss: 1.2891 - learning_rate: 4.6875e-06
# [18:25:37] Epoca 7 avviata
# Epoch 7/50
# 1003/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6886 - auc: 0.9420 - loss: 0.7324[18:26:03] Epoca 7 completata in 26.5s - loss=0.7303 | accuracy=0.6886 | auc=0.9423 | val_loss=1.2889 | val_accuracy=0.5440 | val_auc=0.8723 | lr=4.69e-06
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 27s 26ms/step - accuracy: 0.6886 - auc: 0.9423 - loss: 0.7303 - val_accuracy: 0.5440 - val_auc: 0.8723 - val_loss: 1.2889 - learning_rate: 4.6875e-06
# [18:26:03] Epoca 8 avviata
# Epoch 8/50
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6852 - auc: 0.9427 - loss: 0.7289[18:26:28] Epoca 8 completata in 25.0s - loss=0.7243 | accuracy=0.6884 | auc=0.9431 | val_loss=1.2915 | val_accuracy=0.5417 | val_auc=0.8717 | lr=2.34e-06
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 25s 25ms/step - accuracy: 0.6884 - auc: 0.9431 - loss: 0.7243 - val_accuracy: 0.5417 - val_auc: 0.8717 - val_loss: 1.2915 - learning_rate: 2.3438e-06
# [18:26:28] Epoca 9 avviata
# Epoch 9/50
# 1004/1005 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6924 - auc: 0.9431 - loss: 0.7269[18:26:54] Epoca 9 completata in 25.6s - loss=0.7237 | accuracy=0.6928 | auc=0.9431 | val_loss=1.2910 | val_accuracy=0.5422 | val_auc=0.8721 | lr=2.34e-06
# 1005/1005 ━━━━━━━━━━━━━━━━━━━━ 26s 25ms/step - accuracy: 0.6928 - auc: 0.9431 - loss: 0.7237 - val_accuracy: 0.5422 - val_auc: 0.8721 - val_loss: 1.2910 - learning_rate: 2.3438e-06
# [18:26:54] Training phase terminata in 4.2 minuti
# [18:26:54] Migliore val_loss: 1.2747 all'epoca 1
# [18:26:54] Migliore val_loss: 1.2747 all'epoca 1
# [18:26:54] FINE - Training modello (250.2s)

# %% [markdown]
# ### Stampa curve di apprendimento

# %%
plot_training_results_custom(history, model_name, results_figures_dir)
# Out:
# [INFO] Grafici salvati con successo in: c:\Users\Matteo\Documents\GitHub\ProgettoDL_FaceFERward\results\figures\cnn_v1_curves.png

# %% [markdown]
# ## Valutazione finale sul test set

# %%
with timed_step("Valutazione finale MobileNetV2 sul test set"):
    if best_model_path.exists():
        log_step(f"Carico il miglior modello salvato: {best_model_path}")
        model = load_model(best_model_path)

    evaluate_start = perf_counter()
    test_loss, test_accuracy, test_auc = model.evaluate(test_generator, verbose=1)
    evaluate_time_seconds = perf_counter() - evaluate_start

    log_step(f"Test loss: {test_loss:.4f}")
    log_step(f"Test accuracy: {test_accuracy:.4f}")
    log_step(f"Test AUC: {test_auc:.4f}")

    predict_start = perf_counter()
    y_true = test_generator.classes
    y_pred_proba = model.predict(test_generator, verbose=1)
    predict_time_seconds = perf_counter() - predict_start
    y_pred = np.argmax(y_pred_proba, axis=1)

    inference_time_ms_per_image = (predict_time_seconds / test_generator.samples) * 1000

    class_report = classification_report(y_true, y_pred, target_names=target_names)
    class_report_dict = classification_report(
        y_true,
        y_pred,
        target_names=target_names,
        output_dict=True,
    )
    conf_matrix = confusion_matrix(y_true, y_pred)

    log_step("Classification report")
    print(class_report)

    log_step("Confusion matrix")
    print(conf_matrix)

    with open(test_results_path, "w", encoding="utf-8") as f:
        f.write("=== VALUTAZIONE FINALE SUL TEST SET ===\n\n")
        f.write(f"Test Loss: {test_loss:.4f}\n")
        f.write(f"Test Accuracy: {test_accuracy:.4f}\n")
        f.write(f"Test AUC: {test_auc:.4f}\n")
        f.write(f"Macro F1: {class_report_dict['macro avg']['f1-score']:.4f}\n")
        f.write(f"Weighted F1: {class_report_dict['weighted avg']['f1-score']:.4f}\n")
        f.write(f"Inference time: {inference_time_ms_per_image:.4f} ms/image\n\n")
        f.write("=== CLASSIFICATION REPORT ===\n")
        f.write(class_report)
        f.write("\n=== CONFUSION MATRIX ===\n")
        f.write(np.array2string(conf_matrix))

    report_csv_path = results_tables_dir / f"{experiment_dir.name}_classification_report.csv"
    confusion_csv_path = results_tables_dir / f"{experiment_dir.name}_confusion_matrix.csv"
    predictions_csv_path = results_predictions_dir / f"{experiment_dir.name}_test_predictions.csv"
    confusion_fig_path = results_figures_dir / f"{experiment_dir.name}_confusion_matrix.png"

    pd.DataFrame(class_report_dict).transpose().to_csv(report_csv_path)
    pd.DataFrame(conf_matrix, index=target_names, columns=target_names).to_csv(confusion_csv_path)

    predictions_df = pd.DataFrame(
        {
            "filepath": test_generator.filepaths,
            "true_label": [target_names[i] for i in y_true],
            "predicted_label": [target_names[i] for i in y_pred],
        }
    )
    for class_index, class_name in enumerate(target_names):
        predictions_df[f"prob_{class_name}"] = y_pred_proba[:, class_index]
    predictions_df.to_csv(predictions_csv_path, index=False)

    disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=target_names)
    fig, ax = plt.subplots(figsize=(9, 9))
    disp.plot(ax=ax, cmap="Blues", xticks_rotation=45)
    plt.title("Confusion matrix - test set")
    plt.tight_layout()
    fig.savefig(confusion_fig_path, dpi=150, bbox_inches="tight")
    plt.show()

    model_size_mb = best_model_path.stat().st_size / (1024 * 1024) if best_model_path.exists() else 0.0
    total_train_time_seconds = feature_train_time_seconds + fine_tune_train_time_seconds

    config = {
        "model_name": model_name,
        "timestamp": timestamp,
        "pretrained_weights": "imagenet",
        "base_model": "MobileNetV2",
        "input_shape": [IMG_HEIGHT, IMG_WIDTH, 3],
        "batch_size": BATCH_SIZE,
        "feature_epochs": FEATURE_EPOCHS,
        "fine_tune_epochs": FINE_TUNE_EPOCHS,
        "fine_tune_last_layers": FINE_TUNE_LAST_LAYERS,
        "feature_learning_rate": FEATURE_LEARNING_RATE,
        "fine_tune_learning_rate": FINE_TUNE_LEARNING_RATE,
        "optimizer": "Adam",
        "loss": "categorical_crossentropy",
        "metrics": ["accuracy", "auc"],
        "class_weight": {str(k): float(v) for k, v in class_weights.items()},
        "train_dir": str(train_dir.relative_to(project_root)),
        "validation_dir": str(validation_dir.relative_to(project_root)),
        "test_dir": str(test_dir.relative_to(project_root)),
        "output_dir": str(experiment_dir.relative_to(project_root)),
        "total_params": int(model.count_params()),
        "feature_trainable_params": int(trainable_params),
        "fine_tune_trainable_params": int(fine_tune_trainable_params),
        "model_size_mb": float(model_size_mb),
        "feature_train_time_seconds": float(feature_train_time_seconds),
        "fine_tune_train_time_seconds": float(fine_tune_train_time_seconds),
        "total_train_time_seconds": float(total_train_time_seconds),
        "evaluate_time_seconds": float(evaluate_time_seconds),
        "predict_time_seconds": float(predict_time_seconds),
        "inference_time_ms_per_image": float(inference_time_ms_per_image),
        "test_loss": float(test_loss),
        "test_accuracy": float(test_accuracy),
        "test_auc": float(test_auc),
        "macro_f1": float(class_report_dict["macro avg"]["f1-score"]),
        "weighted_f1": float(class_report_dict["weighted avg"]["f1-score"]),
        "best_val_loss": float(best_val_loss),
        "best_val_loss_epoch": int(best_epoch),
        "best_val_accuracy": float(best_val_accuracy),
        "best_val_accuracy_epoch": int(best_val_accuracy_epoch),
        "best_val_auc": float(best_val_auc),
        "best_val_auc_epoch": int(best_val_auc_epoch),
    }

    with open(config_path, "w", encoding="utf-8") as f:
        json.dump(config, f, indent=2)

    with open(log_output_path, "w", encoding="utf-8") as f:
        f.write(f"Modello: {model_name}\n")
        f.write(f"Data: {timestamp}\n")
        f.write(f"Base model: MobileNetV2 pretrained on ImageNet\n")
        f.write(f"Migliore val_loss: {best_val_loss:.4f} all'epoca {best_epoch}\n")
        f.write(f"Test accuracy: {test_accuracy:.4f}\n")
        f.write(f"Test AUC: {test_auc:.4f}\n")
        f.write(f"Macro F1: {class_report_dict['macro avg']['f1-score']:.4f}\n")
        f.write(f"Weighted F1: {class_report_dict['weighted avg']['f1-score']:.4f}\n")
        f.write(f"Training totale: {total_train_time_seconds / 60:.1f} minuti\n")
        f.write(f"Inference time: {inference_time_ms_per_image:.4f} ms/image\n")

    comparison_path = results_tables_dir / "models_comparison.csv"
    comparison_row = {
        "experiment_name": experiment_dir.name,
        "model_name": model_name,
        "base_model": "MobileNetV2",
        "pretrained_weights": "imagenet",
        "input_size": f"{IMG_HEIGHT}x{IMG_WIDTH}x3",
        "test_accuracy": float(test_accuracy),
        "macro_f1": float(class_report_dict["macro avg"]["f1-score"]),
        "weighted_f1": float(class_report_dict["weighted avg"]["f1-score"]),
        "test_auc": float(test_auc),
        "num_params": int(model.count_params()),
        "model_size_mb": float(model_size_mb),
        "train_time_seconds": float(total_train_time_seconds),
        "inference_time_ms_per_image": float(inference_time_ms_per_image),
        "experiment_dir": str(experiment_dir.relative_to(project_root)),
    }

    if comparison_path.exists():
        comparison_df = pd.read_csv(comparison_path)
        comparison_df = comparison_df[comparison_df["experiment_name"] != experiment_dir.name]
        comparison_df = pd.concat([comparison_df, pd.DataFrame([comparison_row])], ignore_index=True)
    else:
        comparison_df = pd.DataFrame([comparison_row])
    comparison_df.to_csv(comparison_path, index=False)

    log_step(f"Risultati del test salvati in: {test_results_path}")
    log_step(f"Config salvata in: {config_path}")
    log_step(f"Classification report CSV salvato in: {report_csv_path}")
    log_step(f"Confusion matrix CSV salvata in: {confusion_csv_path}")
    log_step(f"Predizioni test salvate in: {predictions_csv_path}")
    log_step(f"Confusion matrix PNG salvata in: {confusion_fig_path}")
    log_step(f"Tabella confronto modelli aggiornata in: {comparison_path}")
# Out:
# [17:55:14] INIZIO - Valutazione finale MobileNetV2 sul test set
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - accuracy: 0.2056 - auc: 0.5627 - loss: 2.1958
# [17:55:25] Test loss: 2.1958
# [17:55:25] Test accuracy: 0.2056
# [17:55:25] Test AUC: 0.5627
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step
# [17:55:35] Classification report
#               precision    recall  f1-score   support
#
#        angry       0.09      0.04      0.05       958
#      disgust       0.01      0.05      0.02       111
#         fear       0.19      0.08      0.11      1024
#        happy       0.29      0.46      0.36      1774
#      neutral       0.16      0.22      0.19      1233
#          sad       0.23      0.07      0.11      1247
#     surprise       0.16      0.21      0.18       831
#
#     accuracy                           0.21      7178
#    macro avg       0.16      0.16      0.15      7178
# weighted avg       0.20      0.21      0.18      7178
#
# [17:55:35] Confusion matrix
# [[ 37  52  60 363 283  57 106]
#  [  7   5  13  41  30   5  10]
#  [ 61  59  79 404 222  51 148]
#  [ 73  60  73 821 355  87 305]
#  [ 84  91  54 477 270  56 201]
#  [ 89  91  96 378 330  89 174]
#  [ 57  28  39 315 174  43 175]]
# [17:55:35] FINE - Valutazione finale MobileNetV2 sul test set (20.7s)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 78
#      74     fig.savefig(confusion_fig_path, dpi=150, bbox_inches="tight")
#      75     plt.show()
#      76
#      77     model_size_mb = best_model_path.stat().st_size / (1024 * 1024) if best_model_path.exists() else 0.0
# ---> 78     total_train_time_seconds = feature_train_time_seconds + fine_tune_train_time_seconds
#      79
#      80     config = {
#      81         "model_name": model_name,
#
# NameError: name 'feature_train_time_seconds' is not defined

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import cv2

experiment_dir = Path(r"C:\Users\Matteo\Documents\GitHub\ProgettoDL_FaceFERward\experiments\20260628_181653_mobilenetv2_transfer")
model_path = experiment_dir / "model.keras"

log_step(f"Caricamento del modello da: {model_path}...")
model = tf.keras.models.load_model(model_path)

log_step("Generazione delle mappe Grad-CAM per 12 immagini di esempio...")

def get_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    """Genera la heatmap Grad-CAM nativa identificando i layer in modo dinamico."""
    
    # 1. Recuperiamo i componenti cercando per tipo o stringa parziale
    base_model = model.get_layer("mobilenetv2_1.00_96")
    
    # Cerchiamo i layer successivi dinamicamente per evitare il problema dei suffissi numerici (_1, _2...)
    gap_layer = None
    dropout_layer = None
    dense_layer = None
    
    for layer in model.layers:
        if "global_average_pooling2d" in layer.name:
            gap_layer = layer
        elif "dropout" in layer.name:
            dropout_layer = layer
        elif "dense" in layer.name:
            dense_layer = layer

    # Controllo di sicurezza se qualcosa dovesse mancare
    if not all([gap_layer, dropout_layer, dense_layer]):
        raise ValueError("Impossibile mappare i layer custom. Verifica la struttura del modello.")
    
    # 2. Creiamo un modello intermedio solo per la parte convoluzionale di MobileNetV2
    base_grad_model = tf.keras.models.Model(
        base_model.inputs, 
        base_model.get_layer(last_conv_layer_name).output
    )
    
    # 3. Eseguiamo il passaggio in avanti nel GradientTape (il resto rimane identico)
    with tf.GradientTape() as tape:
        last_conv_layer_output = base_grad_model(img_array)
        
        x = gap_layer(last_conv_layer_output)
        x = dropout_layer(x)
        preds = dense_layer(x)
        
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # 4. Calcolo dei gradienti
    grads = tape.gradient(class_channel, last_conv_layer_output)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    
    # 5. Generazione della heatmap
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    heatmap = tf.maximum(heatmap, 0) / (tf.reduce_max(heatmap) + 1e-10)
    return heatmap.numpy()


# 1. Identifichiamo l'ultimo livello convoluzionale di MobileNetV2
last_conv_layer_name = "out_relu" 

# 2. Resettiamo il generatore ed estraiamo i dati per 12 immagini
test_generator.reset()

gradcam_images = []
gradcam_labels_true = []
gradcam_labels_pred = []
gradcam_heatmaps = []

# Cicliamo sul generatore finché non raccogliamo almeno 12 immagini
compiled_images = 0
for x_batch, y_batch in test_generator:
    preds_batch = model.predict(x_batch, verbose=0)
    
    for i in range(len(x_batch)):
        if compiled_images >= 12:
            break
            
        img = x_batch[i]
        true_idx = np.argmax(y_batch[i])
        pred_idx = np.argmax(preds_batch[i])
        
        img_input = np.expand_dims(img, axis=0)
        
        # Generiamo la heatmap per la classe predetta
        heatmap = get_gradcam_heatmap(img_input, model, last_conv_layer_name, pred_index=pred_idx)        
        gradcam_images.append(img)
        gradcam_labels_true.append(target_names[true_idx])
        gradcam_labels_pred.append(target_names[pred_idx])
        gradcam_heatmaps.append(heatmap)
        
        compiled_images += 1
        
    if compiled_images >= 12:
        break

# 3. Creiamo la griglia di visualizzazione (4 righe x 3 colonne)
fig, axes = plt.subplots(4, 3, figsize=(10, 10))
axes = axes.ravel()

for i in range(12):
    img_display = gradcam_images[i]
    if img_display.min() < 0:
        img_display = (img_display + 1.0) / 2.0
    img_display = np.clip(img_display, 0, 1)

    # Ridimensioniamo la heatmap per farla combaciare con l'immagine originale
    heatmap_resized = cv2.resize(gradcam_heatmaps[i], (img_display.shape[1], img_display.shape[0]))
    
    # Convertiamo la heatmap in formato Jet colorato
    heatmap_colored = cv2.applyColorMap(np.uint8(255 * heatmap_resized), cv2.COLORMAP_JET)
    heatmap_colored = cv2.cvtColor(heatmap_colored, cv2.COLOR_BGR2RGB) / 255.0

    # Sovrapponiamo l'immagine originale e la heatmap (risolto errore dtype forzando float64 o calcolo numpy)
    superimposed_img = (img_display * 0.6) + (heatmap_colored * 0.4)
    superimposed_img = np.clip(superimposed_img, 0, 1)

    # Plot nel subplot dedicato
    ax = axes[i]
    ax.imshow(superimposed_img)
    
    title_color = "green" if gradcam_labels_true[i] == gradcam_labels_pred[i] else "red"
    ax.set_title(f"True: {gradcam_labels_true[i]}\nPred: {gradcam_labels_pred[i]}", color=title_color, fontsize=10)
    ax.axis("off")

plt.tight_layout()

# 4. Salviamo la figura generata nel tuo percorso figure
gradcam_fig_path = results_figures_dir / f"{experiment_dir.name}_gradcam_examples.png"
fig.savefig(gradcam_fig_path, dpi=150, bbox_inches="tight")
plt.show()

log_step(f"Esempi Grad-CAM salvati in: {gradcam_fig_path}")
# Out:
# [18:24:33] Caricamento del modello da: C:\Users\Matteo\Documents\GitHub\ProgettoDL_FaceFERward\experiments\20260629_185100_cnn_complex_v1\model.keras...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Matteo\anaconda3\envs\DL\Lib\site-packages\keras\src\saving\serialization_lib.py:737, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     736 try:
# --> 737     instance = cls.from_config(inner_config)
#     738 except TypeError as e:
#
# File c:\Users\Matteo\anaconda3\envs\DL\Lib\site-packages\keras\src\initializers\initializer.py:81, in Initializer.from_config(cls, config)
#      65 """Instantiates an initializer from a configuration dictionary.
#      66
#      67 Example:
#    (...)     79     An `Initializer` instance.
#      80 """
# ---> 81 return cls(**config)
#
# TypeError: GlorotUniform.__init__() got an unexpected keyword argument 'input_axes'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Matteo\anaconda3\envs\DL\Lib\site-packages\keras\src\ops\operation.py:317, in Operation.from_config(cls, config)
#     316 try:
# --> 317     return cls(**config)
#     318 except Exception as e:
#
# File c:\Users\Matteo\anaconda3\envs\DL\Lib\site-packages\keras\src\layers\convolutional\conv2d.py:118, in Conv2D.__init__(self, filters, kernel_size, strides, padding, data_format, dilation_rate, groups, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#      98 def __init__(
#      99     self,
#     100     filters,
#    (...)    116     **kwargs,
#     117 ):
# --> 118     super().__init__(
#     119         rank=2,
#     120         filters=filters,
#     121         kernel_size=kernel_size,
#     122         strides=strides,
#     123         padding=padding,
#     124         data_format=data_format,
#     125         dilation_rate=dilation_rate,
#     126         groups=groups,
#     127         activation=activation,
#     128         use_bias=use_bias,
#     129         kernel_initializer=kernel_initializer,
#     130         bias_initializer=bias_initializer,
#     131         kernel_regularizer=kernel_regularizer,
#     132         bias_regularizer=bias_regularizer,
#     133         activity_regularizer=activity_regularizer,
#     134         kernel_constraint=kernel_constraint,
#     135         bias_constraint=bias_constraint,
#     136         **kwargs,
#     137     )
#
# File c:\Users\Matteo\anaconda3\envs\DL\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:126, in BaseConv.__init__(self, rank, filters, kernel_size, strides, padding, data_format, dilation_rate, groups, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, lora_rank, lora_alpha, **kwargs)
#     125 self.use_bias = use_bias
# --> 126 self.kernel_initializer = initializers.get(kernel_initializer)
#     127 self.bias_initializer = initializers.get(bias_initializer)
#
# File c:\Users\Matteo\anaconda3\envs\DL\Lib\site-packages\keras\src\initializers\__init__.py:133, in get(identifier)
#     132 if isinstance(identifier, dict):
# --> 133     obj = deserialize(identifier)
#     134 elif isinstance(identifier, str):
#
# File c:\Users\Matteo\anaconda3\envs\DL\Lib\site-packages\keras\src\initializers\__init__.py:75, in deserialize(config, custom_objects)
#      74 """Returns a Keras initializer object via its configuration."""
# ---> 75 return serialization_lib.deserialize_keras_object(
#      76     config,
#      77     module_objects=ALL_OBJECTS_DICT,
#      78     custom_objects=custom_objects,
#      79 )
#
# File c:\Users\Matteo\anaconda3\envs\DL\Lib\site-packages\keras\src\saving\serialization_lib.py:600, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     594             return deserialize_keras_object(
#     595                 serialize_with_public_fn(
#     596                     module_objects[config], config, fn_module_name
#     597                 ),
#     598                 custom_objects=custom_objects,
#     599             )
# --> 600         return deserialize_keras_object(
#     601             serialize_with_public_class(
#     602                 module_objects[config], inner_config=inner_config
#     603             ),
#     604             custom_objects=custom_objects,
#     605         )
#     607 if isinstance(config, PLAIN_TYPES):
#
# File c:\Users\Matteo\anaconda3\envs\DL\Lib\site-packages\keras\src\saving\serialization_lib.py:739, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     738 except TypeError as e:
# --> 739     raise TypeError(
#     740         f"{cls} could not be deserialized properly. Please"
#     741         " ensure that components that are Python object"
#     742         " instances (layers, models, etc.) returned by"
#     743         " `get_config()` are explicitly deserialized in the"
#     744         " model's `from_config()` method."
#     745         f"\n\nconfig={config}.\n\nException encountered: {e}"
#     746     )
#     747 build_config = config.get("build_config", None)
#
# TypeError: <class 'keras.src.initializers.random_initializers.GlorotUniform'> could not be deserialized properly. Please ensure that components that are Python object instances (layers, models, etc.) returned by `get_config()` are explicitly deserialized in the model's `from_config()` method.
#
# config={'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None, 'input_axes': None, 'output_axes': None}, 'registered_name': None}.
#
# Exception encountered: GlorotUniform.__init__() got an unexpected keyword argument 'input_axes'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Matteo\anaconda3\envs\DL\Lib\site-packages\keras\src\saving\serialization_lib.py:737, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     736 try:
# --> 737     instance = cls.from_config(inner_config)
#     738 except TypeError as e:
#
# File c:\Users\Matteo\anaconda3\envs\DL\Lib\site-packages\keras\src\ops\operation.py:319, in Operation.from_config(cls, config)
#     318 except Exception as e:
# --> 319     raise TypeError(
#     320         f"Error when deserializing class '{cls.__name__}' using "
#     321         f"config={config}.\n\nException encountered: {e}"
#     322     )
#
# TypeError: Error when deserializing class 'Conv2D' using config={'name': 'conv2d', 'trainable': True, 'dtype': 'float32', 'filters': 32, 'kernel_size': [3, 3], 'strides': [1, 1], 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': [1, 1], 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None, 'input_axes': None, 'output_axes': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': {'module': 'keras.regularizers', 'class_name': 'L2', 'config': {'l2': 0.0001}, 'registered_name': None}, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}.
#
# Exception encountered: <class 'keras.src.initializers.random_initializers.GlorotUniform'> could not be deserialized properly. Please ensure that components that are Python object instances (layers, models, etc.) returned by `get_config()` are explicitly deserialized in the model's `from_config()` method.
#
# config={'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None, 'input_axes': None, 'output_axes': None}, 'registered_name': None}.
#
# Exception encountered: GlorotUniform.__init__() got an unexpected keyword argument 'input_axes'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Matteo\anaconda3\envs\DL\Lib\site-packages\keras\src\saving\serialization_lib.py:737, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     736 try:
# --> 737     instance = cls.from_config(inner_config)
#     738 except TypeError as e:
#
# File c:\Users\Matteo\anaconda3\envs\DL\Lib\site-packages\keras\src\models\sequential.py:390, in Sequential.from_config(cls, config, custom_objects)
#     389 else:
# --> 390     layer = serialization_lib.deserialize_keras_object(
#     391         layer_config,
#     392         custom_objects=custom_objects,
#     393     )
#     394 model.add(layer)
#
# File c:\Users\Matteo\anaconda3\envs\DL\Lib\site-packages\keras\src\saving\serialization_lib.py:739, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     738 except TypeError as e:
# --> 739     raise TypeError(
#     740         f"{cls} could not be deserialized properly. Please"
#     741         " ensure that components that are Python object"
#     742         " instances (layers, models, etc.) returned by"
#     743         " `get_config()` are explicitly deserialized in the"
#     744         " model's `from_config()` method."
#     745         f"\n\nconfig={config}.\n\nException encountered: {e}"
#     746     )
#     747 build_config = config.get("build_config", None)
#
# TypeError: <class 'keras.src.layers.convolutional.conv2d.Conv2D'> could not be deserialized properly. Please ensure that components that are Python object instances (layers, models, etc.) returned by `get_config()` are explicitly deserialized in the model's `from_config()` method.
#
# config={'module': 'keras.layers', 'class_name': 'Conv2D', 'config': {'name': 'conv2d', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'filters': 32, 'kernel_size': [3, 3], 'strides': [1, 1], 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': [1, 1], 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None, 'input_axes': None, 'output_axes': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': {'module': 'keras.regularizers', 'class_name': 'L2', 'config': {'l2': 0.0001}, 'registered_name': None}, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'registered_name': None, 'build_config': {'input_shape': [None, 48, 48, 1]}}.
#
# Exception encountered: Error when deserializing class 'Conv2D' using config={'name': 'conv2d', 'trainable': True, 'dtype': 'float32', 'filters': 32, 'kernel_size': [3, 3], 'strides': [1, 1], 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': [1, 1], 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None, 'input_axes': None, 'output_axes': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': {'module': 'keras.regularizers', 'class_name': 'L2', 'config': {'l2': 0.0001}, 'registered_name': None}, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}.
#
# Exception encountered: <class 'keras.src.initializers.random_initializers.GlorotUniform'> could not be deserialized properly. Please ensure that components that are Python object instances (layers, models, etc.) returned by `get_config()` are explicitly deserialized in the model's `from_config()` method.
#
# config={'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None, 'input_axes': None, 'output_axes': None}, 'registered_name': None}.
#
# Exception encountered: GlorotUniform.__init__() got an unexpected keyword argument 'input_axes'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 11
#       7 experiment_dir = Path(r"C:\Users\Matteo\Documents\GitHub\ProgettoDL_FaceFERward\experiments\20260629_185100_cnn_complex_v1")
#       8 model_path = experiment_dir / "model.keras"
#       9
#      10 log_step(f"Caricamento del modello da: {model_path}...")
# ---> 11 model = tf.keras.models.load_model(model_path)
#      12
#      13 log_step("Generazione delle mappe Grad-CAM per 12 immagini di esempio...")
#      14
#
# File c:\Users\Matteo\anaconda3\envs\DL\Lib\site-packages\keras\src\saving\saving_api.py:188, in load_model(filepath, custom_objects, compile, safe_mode)
#     185         is_keras_zip = True
#     187 if is_keras_zip or is_keras_dir or is_hf:
# --> 188     return saving_lib.load_model(
#     189         filepath,
#     190         custom_objects=custom_objects,
#     191         compile=compile,
#     192         safe_mode=safe_mode,
#     193     )
#     194 if str(filepath).endswith((".h5", ".hdf5")):
#     195     return legacy_h5_format.load_model_from_hdf5(
#     196         filepath,
#     197         custom_objects=custom_objects,
#     198         compile=compile,
#     199         safe_mode=safe_mode,
#     200     )
#
# File c:\Users\Matteo\anaconda3\envs\DL\Lib\site-packages\keras\src\saving\saving_lib.py:365, in load_model(filepath, custom_objects, compile, safe_mode)
#     360     raise ValueError(
#     361         "Invalid filename: expected a `.keras` extension. "
#     362         f"Received: filepath={filepath}"
#     363     )
#     364 with open(filepath, "rb") as f:
# --> 365     return _load_model_from_fileobj(
#     366         f, custom_objects, compile, safe_mode
#     367     )
#
# File c:\Users\Matteo\anaconda3\envs\DL\Lib\site-packages\keras\src\saving\saving_lib.py:442, in _load_model_from_fileobj(fileobj, custom_objects, compile, safe_mode)
#     439 with zf.open(_CONFIG_FILENAME, "r") as f:
#     440     config_json = f.read()
# --> 442 model = _model_from_config(
#     443     config_json, custom_objects, compile, safe_mode
#     444 )
#     446 all_filenames = zf.namelist()
#     447 extract_dir = None
#
# File c:\Users\Matteo\anaconda3\envs\DL\Lib\site-packages\keras\src\saving\saving_lib.py:431, in _model_from_config(config_json, custom_objects, compile, safe_mode)
#     429 # Construct the model from the configuration file in the archive.
#     430 with ObjectSharingScope():
# --> 431     model = deserialize_keras_object(
#     432         config_dict, custom_objects, safe_mode=safe_mode
#     433     )
#     434 return model
#
# File c:\Users\Matteo\anaconda3\envs\DL\Lib\site-packages\keras\src\saving\serialization_lib.py:739, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     737     instance = cls.from_config(inner_config)
#     738 except TypeError as e:
# --> 739     raise TypeError(
#     740         f"{cls} could not be deserialized properly. Please"
#     741         " ensure that components that are Python object"
#     742         " instances (layers, models, etc.) returned by"
#     743         " `get_config()` are explicitly deserialized in the"
#     744         " model's `from_config()` method."
#     745         f"\n\nconfig={config}.\n\nException encountered: {e}"
#     746     )
#     747 build_config = config.get("build_config", None)
#     748 if build_config and not instance.built:
#
# TypeError: <class 'keras.src.models.sequential.Sequential'> could not be deserialized properly. Please ensure that components that are Python object instances (layers, models, etc.) returned by `get_config()` are explicitly deserialized in the model's `from_config()` method.
#
# config={'module': 'keras', 'class_name': 'Sequential', 'config': {'name': 'cnn_complex_v1', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None, 'shared_object_id': 2223266879760}, 'layers': [{'module': 'keras.layers', 'class_name': 'InputLayer', 'config': {'batch_shape': [None, 48, 48, 1], 'dtype': 'float32', 'sparse': False, 'ragged': False, 'name': 'input_layer', 'optional': False}, 'registered_name': None}, {'module': 'keras.layers', 'class_name': 'Conv2D', 'config': {'name': 'conv2d', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'filters': 32, 'kernel_size': [3, 3], 'strides': [1, 1], 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': [1, 1], 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None, 'input_axes': None, 'output_axes': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': {'module': 'keras.regularizers', 'class_name': 'L2', 'config': {'l2': 0.0001}, 'registered_name': None}, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'registered_name': None, 'build_config': {'input_shape': [None, 48, 48, 1]}}, {'module': 'keras.layers', 'class_name': 'BatchNormalization', 'config': {'name': 'batch_normalization', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None, 'shared_object_id': 2223266879760}, 'axis': -1, 'momentum': 0.99, 'epsilon': 0.001, 'center': True, 'scale': True, 'beta_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'gamma_initializer': {'module': 'keras.initializers', 'class_name': 'Ones', 'config': {}, 'registered_name': None}, 'moving_mean_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'moving_variance_initializer': {'module': 'keras.initializers', 'class_name': 'Ones', 'config': {}, 'registered_name': None}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None, 'synchronized': False, 'renorm': False, 'renorm_clipping': None, 'renorm_momentum': 0.99}, 'registered_name': None, 'build_config': {'input_shape': [None, 48, 48, 32]}}, {'module': 'keras.layers', 'class_name': 'Activation', 'config': {'name': 'activation', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None, 'shared_object_id': 2223266879760}, 'activation': 'relu'}, 'registered_name': None}, {'module': 'keras.layers', 'class_name': 'Conv2D', 'config': {'name': 'conv2d_1', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None, 'shared_object_id': 2223266879760}, 'filters': 32, 'kernel_size': [3, 3], 'strides': [1, 1], 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': [1, 1], 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None, 'input_axes': None, 'output_axes': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': {'module': 'keras.regularizers', 'class_name': 'L2', 'config': {'l2': 0.0001}, 'registered_name': None, 'shared_object_id': 2223294293936}, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'registered_name': None, 'build_config': {'input_shape': [None, 48, 48, 32] ...
#
# Exception encountered: <class 'keras.src.layers.convolutional.conv2d.Conv2D'> could not be deserialized properly. Please ensure that components that are Python object instances (layers, models, etc.) returned by `get_config()` are explicitly deserialized in the model's `from_config()` method.
#
# config={'module': 'keras.layers', 'class_name': 'Conv2D', 'config': {'name': 'conv2d', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'filters': 32, 'kernel_size': [3, 3], 'strides': [1, 1], 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': [1, 1], 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None, 'input_axes': None, 'output_axes': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': {'module': 'keras.regularizers', 'class_name': 'L2', 'config': {'l2': 0.0001}, 'registered_name': None}, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'registered_name': None, 'build_config': {'input_shape': [None, 48, 48, 1]}}.
#
# Exception encountered: Error when deserializing class 'Conv2D' using config={'name': 'conv2d', 'trainable': True, 'dtype': 'float32', 'filters': 32, 'kernel_size': [3, 3], 'strides': [1, 1], 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': [1, 1], 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None, 'input_axes': None, 'output_axes': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': {'module': 'keras.regularizers', 'class_name': 'L2', 'config': {'l2': 0.0001}, 'registered_name': None}, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}.
#
# Exception encountered: <class 'keras.src.initializers.random_initializers.GlorotUniform'> could not be deserialized properly. Please ensure that components that are Python object instances (layers, models, etc.) returned by `get_config()` are explicitly deserialized in the model's `from_config()` method.
#
# config={'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None, 'input_axes': None, 'output_axes': None}, 'registered_name': None}.
#
# Exception encountered: GlorotUniform.__init__() got an unexpected keyword argument 'input_axes'

# %% [markdown]
# ## Note per il confronto
#
# Questa run serve per confrontare la CNN custom con un modello pre-addestrato.
#
# Per la presentazione e il README usare:
#
# - `experiments/<run>/{config.json, model.keras, training_history.csv, training_log.txt, test_results.txt}`
# - `results/tables/models_comparison.csv`
# - `results/figures/<run>_training_curves.png`
# - `results/figures/<run>_confusion_matrix.png`
# - `results/predictions/<run>_test_predictions.csv`
